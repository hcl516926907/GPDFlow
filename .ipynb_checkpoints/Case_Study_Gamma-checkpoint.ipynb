# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import normflows as nf
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from tqdm import tqdm
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def sim_revexp_u_mgpd(n, d, a, beta, sig, gamma, MGPD=True, std=False):
    lam = np.exp(beta)
    Y = np.zeros((n, d))
    C = 1 / np.min(lam)
    k = 0

    while k < n:
        U = np.random.uniform(0, 1, d)
        W = (U ** a) / lam
        R = np.random.uniform(0, C)
        
        Ind = R < np.max(W)
        
        if Ind:
            Y[k, :] = W / R
            k += 1

    if std and not MGPD:
        return np.log(Y)

    X = []
    for j in range(d):
        if gamma[j] != 0:
            X.append(sig[j] * (Y[:, j] ** gamma[j] - 1) / gamma[j])
        else:
            X.append(sig[j] * np.log(Y[:, j]))
    X = np.column_stack(X)

    if MGPD and not std:
        return X
    if std and MGPD:
        return {'X': X, 'Z': np.log(Y)}

# %%
n_samples = 10000
d = 2
a = np.array([50,50])
beta = np.array([0, 0])
sig = np.array([1,1])
gamma = np.array([0, 0])

samples = sim_revexp_u_mgpd(n_samples, d, a, beta, sig, gamma)

# Visualize the samples
plt.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.xlim([0,10])
plt.ylim([0,10])
plt.title('Scatter plot of 1000 samples from the MGPD')
plt.grid(True)
plt.show()

# %%
mean = [0, 0]
cov = [[3, 0.5], [0.5, 2]] 
x, y = np.random.multivariate_normal(mean, cov, 50000).T
samples = np.stack([x,y],axis=1)
u = np.quantile(samples, 0.995,axis=0)
print(u)
samples = samples[(samples[:,0] > u[0] ) | (samples[:,1] > u[1] ),:]
u = u.reshape(1,-1)
samples = samples - u
plt.scatter(samples[:, 0], samples[:, 1], alpha=1)
# plt.xlim([0,5])
# plt.ylim([0,5])
plt.show()
# Out:
# [4.45287587 3.6521647 ]

# %%
samples.shape
# Out:
# (498, 2)

# %%
class DataTransform(nn.Module):
    """
    Elementwise transform:
      If gamma_j = 0:
        forward_transform(y_j): x_j = sigma_j * y_j
        inverse_transform(x_j): y_j = x_j / sigma_j
      Otherwise (gamma_j != 0):
        forward_transform(y_j): x_j = sigma_j * [exp(gamma_j * y_j) - 1] / gamma_j
        inverse_transform(x_j): y_j = (1 / gamma_j)* log(1 + gamma_j * x_j / sigma_j)
    """

    def __init__(self, dim, device):
        super().__init__()
        self.dim = dim
        # Store log_sigma so sigma = exp(log_sigma) > 0
        self.log_sigma = nn.Parameter(torch.zeros(dim, device=device))
        # gamma can be any real value
        self.gamma = nn.Parameter(torch.zeros(dim, device=device)+1e-6)

    def forward_transform(self, y):
        """
        y -> x
        """
        sigma = torch.exp(self.log_sigma)  # shape (dim,)
        sigma = torch.clamp(sigma, min = 1e-6, max = 1e6)
        gamma = self.gamma                # shape (dim,)
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))
        
        # We'll do it elementwise, but in a vectorized way.
        # y and x are shape (batch_size, dim).
    
        x_out = torch.zeros_like(y)

        # For gamma_j = 0 => x_j = sigma_j * y_j
        # For gamma_j != 0 => x_j = sigma_j*(exp(gamma_j*y_j) - 1)/gamma_j
        # We can use torch.where(...) to handle each dimension separately.

        # Expand so shapes match for broadcasting
        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

        # Exponential case: x_j = sigma_j*(exp(gamma_j*y_j) - 1)/gamma_j
        x_out = sigma * (torch.exp(torch.clamp(gamma * y, max=10)) - 1.0) / gamma

        return x_out

    def inverse_transform(self, x):
        """
        x -> y
        """
        sigma = torch.exp(self.log_sigma)  # shape (dim,)
        sigma = torch.clamp(sigma, min = 1e-6, max = 1e6)
        gamma = self.gamma                # shape (dim,)
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))

        y_out = torch.zeros_like(x)

        # For gamma_j = 0 => y_j = x_j / sigma_j
        # For gamma_j != 0 => y_j = (1/gamma_j)* log(1 + gamma_j*x_j / sigma_j)
        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

#         gamma_is_zero = (gamma.abs() < 1e-6)

#         # Linear case: y_j = x_j / sigma_j
#         y_linear = x / sigma

        # Exponential (inverse) case: y_j = (1/gamma_j)* log(1 + gamma_j*x_j / sigma_j)
        inside = 1.0 + (gamma * x) / sigma
        inside = torch.clamp(inside, min=1e-12) 
        y_out = (1.0 / gamma) * torch.log(inside)

#         y_out = torch.where(gamma_is_zero, y_linear, y_exp)
        return y_out

    def forward(self, z, reverse=False):
        """
        For normflows compatibility:
          - If reverse=False: we do y->x
          - If reverse=True: we do x->y
        """
        if not reverse:
            return self.forward_transform(z)
        else:
            return self.inverse_transform(z)

# %%
class T_mGPD_NF(nn.Module):
    """
    Interpreting:
       x = observed data (size=dim)
       y = standardized data
    We have:

      DataTransform.forward_transform(y)   = x
      DataTransform.inverse_transform(x)   = y

    So in 'forward(x)', to get minus log-likelihood of data x:
       1) We do y = inverse_transform(x)
       2) log_p_flow(y) = flow_model.log_prob(y)
       3) The log-det Jacobian of x->y is the sum of log(d y_i / d x_i).
          We'll compute that from the known formula for inverse_transform.
    """
    def __init__(self, dim, flow, device, s_min , s_max, num_integration_points, penalty_lambda):
        super().__init__()
        self.dim = dim
        # Learnable data transformation
        self.data_transform = DataTransform(dim, device)
        # RealNVP flow model
        self.flow_model = flow
        self.device = device
        self.s_values = torch.linspace(s_min, s_max, num_integration_points, device=device)
        self.s_values = self.s_values.reshape(-1, 1, 1)
        self.s_min = s_min
        self.s_max = s_max
        self.num_integration_points = num_integration_points
        self.penalty_lambda = penalty_lambda
        
    def log_integral_f_T(self, data):
            # Expand batch_x to match s_values
        batch_size = data.shape[0]
        dim = data.shape[1]
        
        x_expanded = data.unsqueeze(0)  # Shape (1, effective_batch_size, dim)
        x_expanded = x_expanded.expand(self.num_integration_points, -1, -1)  # Shape (num_points, batch_size, dim)

        # Expand s_values to match batch size and dimension
        s_expanded = self.s_values.expand(-1, batch_size, 1)  # Shape (num_points, batch_size, 1)

        # Compute x + s for all s_values
        x_plus_s = x_expanded + s_expanded  # Broadcasting over the last dimension
        x_plus_s = x_plus_s.reshape(-1, dim)  # Flatten to (num_points * batch_size, dim)

        log_f_T = self.flow_model.log_prob(x_plus_s)  # Shape (num_points * batch_size,)
        log_integrand = log_f_T.reshape(self.num_integration_points, batch_size)
        
        # 1. log-sum-exp over 'num_points' dimension
        max_vals, _ = torch.max(log_integrand, dim=0, keepdim=True)  # shape (1, batch_size)
        stable_exp = torch.exp(log_integrand - max_vals)             # shape (num_points, batch_size)
        
        delta_s = (self.s_max - self.s_min) / (self.num_integration_points - 1)
        sum_exp = torch.trapz(stable_exp, dx=delta_s, dim=0)         # shape (batch_size,)
        # 2. Now put the max_vals back in:
        log_integral = max_vals.squeeze(0) + torch.log(sum_exp + 1e-40)  # shape (batch_size,)
        
        return log_integral
    
    def log_prob_T_mGPD_std(self, data):
        log_integral = self.log_integral_f_T(data)
        max_T = torch.max(data, dim=1)[0]
        
        log_prob = log_integral - max_T
        return log_prob
    
    
        

    def forward(self, x_data):
        """
        Return minus log p_data(x_data).
        We do:
          y = T_inv(x_data)  [since T_inv is x->y]
          log p_data(x_data) = log p_flow(y) + log|det(d y / d x)|
        """
        # 1) x->y
        y = self.data_transform.inverse_transform(x_data)

        # 2) log prob under flow
        log_prob_y = self.log_prob_T_mGPD_std(y)

        # 3) log | det dy/dx |
        #    From y_i = 1/gamma_i * log(1 + gamma_i*x_i / sigma_i),
        #    dy_i/dx_i = 1 / [sigma_i + gamma_i * x_i].
        sigma = torch.exp(self.data_transform.log_sigma)  # shape (dim,)
        gamma = self.data_transform.gamma                 # shape (dim,)

        sigma = torch.clamp(sigma, min = 0.01, max = 100)
        
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))

        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

        # Build inside = sigma + gamma*x
        inside = sigma + gamma * x_data

        # log_abs_detJ per sample = - sum_j log(inside_j)
        log_abs_detJ = -torch.sum(torch.log(inside.abs() + 1e-12), dim=1)
        
        # => log p(x_data) = log p(y) + log|det dy/dx|
        log_prob_x = log_prob_y + log_abs_detJ
        
        ######## Soft penalty: penalize negative (sigma_j + gamma_j*x_j)
        negative_part = torch.relu(-inside)  # = max(0, -(inside)) => positive if inside<0
        # penalty = sum_j [ negative_part^2 ] over j, average over batch
        penalty_per_sample = (negative_part ** 2).sum(dim=1)
        penalty = self.penalty_lambda * penalty_per_sample.mean()
        
        return -log_prob_x.mean() +  penalty 

    def sample(self, n_samples=1):
        """
        Sample from the learned distribution in x-space by:
          1) Sample y ~ flow
          2) Convert y->x using forward_transform
        """
        self.flow_model.eval()
        samples_T,_ = self.flow_model.sample(n_samples)
        self.flow_model.train()
        
        samples_T_max = torch.max(samples_T,axis=1,keepdim=True)[0]
        samples_T_1 = samples_T - samples_T_max
        
        samples_E  = torch.empty(n_samples, device=self.device)
        samples_E = samples_E.exponential_(1.0).unsqueeze(1)
        
        samples_y = samples_E + samples_T_1

        samples_x = self.data_transform.forward_transform(samples_y)  # y->x
        return samples_x, samples_y, samples_T

# %%
data = torch.tensor(samples, dtype=torch.float, device = device)

# %%
memory = torch.cuda.memory_allocated(device) /10**9
print('{:.2f}G GPU memory allocated'.format(memory))
# Out:
# 0.03G GPU memory allocated

# %%
dim = 2
base = nf.distributions.base.DiagGaussian(2)

num_layers = 4
flows = []
for i in range(num_layers):
    # Neural network with two hidden layers having 64 units each
    # Last layer is initialized by zeros making training more stable
    param_map = nf.nets.MLP([1, 5, 5, 2], init_zeros=True)
    # Add flow layer
    flows.append(nf.flows.AffineCouplingBlock(param_map))
    # Swap dimensions
    flows.append(nf.flows.Permute(2, mode='swap'))
    
f_T_model = nf.NormalizingFlow(base, flows)
f_T_model = f_T_model.to(device)


batch_size = 32
num_iterations = 3000
loss_history = []
show_iter = 200

model = T_mGPD_NF(dim=2, flow =f_T_model, device=device, s_min=-10,
                  s_max = 10, num_integration_points=1000, penalty_lambda=10000)

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4,weight_decay=1e-5)
optimizer = torch.optim.Adam([
    {'params': model.flow_model.parameters(), 'lr': 1e-3},  # Flow layers
    {'params': model.data_transform.log_sigma, 'lr': 1e-2},  # Faster for log_sigma
    {'params': model.data_transform.gamma, 'lr': 1e-2}       # Faster for gamma
])
# for name, param in model.named_parameters():
#     print(name, param)

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_iterations)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#     optimizer, mode='min', factor=0.5, patience=10, verbose=True
# )
for it in range(num_iterations):
    # Sample a batch of data from h_U
    idx = np.random.choice(data.shape[0], batch_size, replace=False)
    x_data = data[idx]  # Shape (batch_size, dim)
    
    batch_loss = model(x_data)
    
    # Backpropagation
    optimizer.zero_grad()
    batch_loss.backward()
    
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)

    
    optimizer.step()
    
    # Record loss
    loss_history.append(batch_loss.item())
    
    if torch.isnan(batch_loss) or torch.isinf(batch_loss):
        print("NaN or Inf detected!")
        break
    
    if it % 1 == 0:
        print(f"Iteration {it}, Loss: {batch_loss.item()}")
        current_lr = optimizer.param_groups[0]['lr']
    
        print(f"Iteration {it} - Learning Rate: {current_lr}")
        # Debugging: Print shapes
    if it % show_iter == 0:
        
        samples_obs, samples_std, samples_T= model.sample(n_samples)
        
        samples_obs, samples_std, samples_T= model.sample(n_samples)
        plt.figure(figsize=(8,8))
        plt.subplot(2, 2, 1)
        plt.scatter(samples_obs[:,0].cpu().data.numpy(), samples_obs[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples on observational scale')
        plt.subplot(2, 2, 2)
        plt.scatter(samples_std[:,0].cpu().data.numpy(), samples_std[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples on standardized scale')
        plt.subplot(2, 2, 3)
        plt.scatter(samples_T[:,0].cpu().data.numpy(), samples_T[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples from Normalizing Flow')
        plt.show()
    

    scheduler.step()
    
# Plot the training loss
plt.figure()
plt.plot(loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()
# Out:
# Iteration 0, Loss: 4.8012375831604
# Iteration 0 - Learning Rate: 0.001
# Iteration 1, Loss: 5.46473503112793
# Iteration 1 - Learning Rate: 0.0009999997258443472
# Iteration 2, Loss: 5.009182453155518
# Iteration 2 - Learning Rate: 0.0009999989033776897
# Iteration 3, Loss: 6.042954444885254
# Iteration 3 - Learning Rate: 0.0009999975326009292
# Iteration 4, Loss: 6.205252647399902
# Iteration 4 - Learning Rate: 0.0009999956135155687
# Iteration 5, Loss: 5.053290843963623
# Iteration 5 - Learning Rate: 0.0009999931461237132
# Iteration 6, Loss: 5.634875297546387
# Iteration 6 - Learning Rate: 0.0009999901304280684
# Iteration 7, Loss: 5.263116836547852
# Iteration 7 - Learning Rate: 0.0009999865664319413
# Iteration 8, Loss: 4.907268524169922
# Iteration 8 - Learning Rate: 0.0009999824541392403
# Iteration 9, Loss: 4.887399673461914
# Iteration 9 - Learning Rate: 0.000999977793554475
# Iteration 10, Loss: 4.525997638702393
# Iteration 10 - Learning Rate: 0.000999972584682756
# Iteration 11, Loss: 4.54334020614624
# Iteration 11 - Learning Rate: 0.000999966827529796
# Iteration 12, Loss: 4.480754852294922
# Iteration 12 - Learning Rate: 0.000999960522101908
# Iteration 13, Loss: 4.665559768676758
# Iteration 13 - Learning Rate: 0.0009999536684060068
# Iteration 14, Loss: 4.815084457397461
# Iteration 14 - Learning Rate: 0.0009999462664496085
# Iteration 15, Loss: 4.574347972869873
# Iteration 15 - Learning Rate: 0.00099993831624083
# Iteration 16, Loss: 4.065282344818115
# Iteration 16 - Learning Rate: 0.00099992981778839
# Iteration 17, Loss: 4.109781742095947
# Iteration 17 - Learning Rate: 0.000999920771101608
# Iteration 18, Loss: 4.555742263793945
# Iteration 18 - Learning Rate: 0.0009999111761904043
# Iteration 19, Loss: 4.113910675048828
# Iteration 19 - Learning Rate: 0.0009999010330653017
# Iteration 20, Loss: 3.900301218032837
# Iteration 20 - Learning Rate: 0.0009998903417374227
# Iteration 21, Loss: 4.4496169090271
# Iteration 21 - Learning Rate: 0.0009998791022184919
# Iteration 22, Loss: 3.675747871398926
# Iteration 22 - Learning Rate: 0.0009998673145208347
# Iteration 23, Loss: 3.8899405002593994
# Iteration 23 - Learning Rate: 0.0009998549786573781
# Iteration 24, Loss: 3.9311130046844482
# Iteration 24 - Learning Rate: 0.0009998420946416495
# Iteration 25, Loss: 4.041873455047607
# Iteration 25 - Learning Rate: 0.000999828662487778
# Iteration 26, Loss: 3.920663356781006
# Iteration 26 - Learning Rate: 0.000999814682210494
# Iteration 27, Loss: 3.961988687515259
# Iteration 27 - Learning Rate: 0.0009998001538251279
# Iteration 28, Loss: 3.8407065868377686
# Iteration 28 - Learning Rate: 0.000999785077347612
# Iteration 29, Loss: 3.774465799331665
# Iteration 29 - Learning Rate: 0.0009997694527944798
# Iteration 30, Loss: 3.7892112731933594
# Iteration 30 - Learning Rate: 0.0009997532801828653
# Iteration 31, Loss: 3.8058714866638184
# Iteration 31 - Learning Rate: 0.0009997365595305037
# Iteration 32, Loss: 4.102146148681641
# Iteration 32 - Learning Rate: 0.0009997192908557317
# Iteration 33, Loss: 3.838857412338257
# Iteration 33 - Learning Rate: 0.0009997014741774859
# Iteration 34, Loss: 4.1465864181518555
# Iteration 34 - Learning Rate: 0.000999683109515305
# Iteration 35, Loss: 3.5967793464660645
# Iteration 35 - Learning Rate: 0.0009996641968893275
# Iteration 36, Loss: 3.900902271270752
# Iteration 36 - Learning Rate: 0.000999644736320294
# Iteration 37, Loss: 3.5728635787963867
# Iteration 37 - Learning Rate: 0.0009996247278295453
# Iteration 38, Loss: 3.8357880115509033
# Iteration 38 - Learning Rate: 0.000999604171439023
# Iteration 39, Loss: 3.6369316577911377
# Iteration 39 - Learning Rate: 0.0009995830671712697
# Iteration 40, Loss: 3.854585886001587
# Iteration 40 - Learning Rate: 0.0009995614150494288
# Iteration 41, Loss: 3.6751861572265625
# Iteration 41 - Learning Rate: 0.0009995392150972445
# Iteration 42, Loss: 3.8518266677856445
# Iteration 42 - Learning Rate: 0.000999516467339062
# Iteration 43, Loss: 3.7411928176879883
# Iteration 43 - Learning Rate: 0.0009994931717998267
# Iteration 44, Loss: 3.49621844291687
# Iteration 44 - Learning Rate: 0.0009994693285050853
# Iteration 45, Loss: 3.647149085998535
# Iteration 45 - Learning Rate: 0.0009994449374809847
# Iteration 46, Loss: 3.6483511924743652
# Iteration 46 - Learning Rate: 0.0009994199987542725
# Iteration 47, Loss: 3.8722116947174072
# Iteration 47 - Learning Rate: 0.0009993945123522973
# Iteration 48, Loss: 3.7089123725891113
# Iteration 48 - Learning Rate: 0.0009993684783030084
# Iteration 49, Loss: 3.631535053253174
# Iteration 49 - Learning Rate: 0.0009993418966349546
# Iteration 50, Loss: 3.5520005226135254
# Iteration 50 - Learning Rate: 0.0009993147673772863
# Iteration 51, Loss: 3.9585418701171875
# Iteration 51 - Learning Rate: 0.0009992870905597543
# Iteration 52, Loss: 3.6545839309692383
# Iteration 52 - Learning Rate: 0.0009992588662127095
# Iteration 53, Loss: 3.802692413330078
# Iteration 53 - Learning Rate: 0.000999230094367103
# Iteration 54, Loss: 3.764946937561035
# Iteration 54 - Learning Rate: 0.000999200775054487
# Iteration 55, Loss: 3.6320853233337402
# Iteration 55 - Learning Rate: 0.0009991709083070135
# Iteration 56, Loss: 3.377124309539795
# Iteration 56 - Learning Rate: 0.0009991404941574354
# Iteration 57, Loss: 3.4529852867126465
# Iteration 57 - Learning Rate: 0.0009991095326391053
# Iteration 58, Loss: 3.687237024307251
# Iteration 58 - Learning Rate: 0.0009990780237859763
# Iteration 59, Loss: 3.63826847076416
# Iteration 59 - Learning Rate: 0.0009990459676326017
# Iteration 60, Loss: 3.707467555999756
# Iteration 60 - Learning Rate: 0.0009990133642141352
# Iteration 61, Loss: 3.5851757526397705
# Iteration 61 - Learning Rate: 0.0009989802135663302
# Iteration 62, Loss: 3.694138526916504
# Iteration 62 - Learning Rate: 0.0009989465157255405
# Iteration 63, Loss: 3.541386604309082
# Iteration 63 - Learning Rate: 0.00099891227072872
# Iteration 64, Loss: 3.178478717803955
# Iteration 64 - Learning Rate: 0.0009988774786134226
# Iteration 65, Loss: 3.653496265411377
# Iteration 65 - Learning Rate: 0.000998842139417802
# Iteration 66, Loss: 3.588026523590088
# Iteration 66 - Learning Rate: 0.000998806253180612
# Iteration 67, Loss: 3.4072818756103516
# Iteration 67 - Learning Rate: 0.0009987698199412061
# Iteration 68, Loss: 3.603111505508423
# Iteration 68 - Learning Rate: 0.0009987328397395381
# Iteration 69, Loss: 3.569436550140381
# Iteration 69 - Learning Rate: 0.0009986953126161612
# Iteration 70, Loss: 3.519047498703003
# Iteration 70 - Learning Rate: 0.0009986572386122283
# Iteration 71, Loss: 3.6031813621520996
# Iteration 71 - Learning Rate: 0.0009986186177694926
# Iteration 72, Loss: 3.435990810394287
# Iteration 72 - Learning Rate: 0.0009985794501303062
# Iteration 73, Loss: 3.594888687133789
# Iteration 73 - Learning Rate: 0.0009985397357376215
# Iteration 74, Loss: 3.48010516166687
# Iteration 74 - Learning Rate: 0.0009984994746349903
# Iteration 75, Loss: 3.41241192817688
# Iteration 75 - Learning Rate: 0.0009984586668665633
# Iteration 76, Loss: 3.4904370307922363
# Iteration 76 - Learning Rate: 0.0009984173124770917
# Iteration 77, Loss: 3.5643391609191895
# Iteration 77 - Learning Rate: 0.0009983754115119256
# Iteration 78, Loss: 3.4315662384033203
# Iteration 78 - Learning Rate: 0.0009983329640170142
# Iteration 79, Loss: 3.4763503074645996
# Iteration 79 - Learning Rate: 0.000998289970038907
# Iteration 80, Loss: 3.851787567138672
# Iteration 80 - Learning Rate: 0.0009982464296247515
# Iteration 81, Loss: 3.7214126586914062
# Iteration 81 - Learning Rate: 0.0009982023428222954
# Iteration 82, Loss: 3.262023448944092
# Iteration 82 - Learning Rate: 0.0009981577096798856
# Iteration 83, Loss: 3.4069228172302246
# Iteration 83 - Learning Rate: 0.0009981125302464672
# Iteration 84, Loss: 3.65236759185791
# Iteration 84 - Learning Rate: 0.0009980668045715855
# Iteration 85, Loss: 3.288808822631836
# Iteration 85 - Learning Rate: 0.000998020532705384
# Iteration 86, Loss: 3.6140074729919434
# Iteration 86 - Learning Rate: 0.0009979737146986055
# Iteration 87, Loss: 3.383047103881836
# Iteration 87 - Learning Rate: 0.000997926350602592
# Iteration 88, Loss: 3.5667216777801514
# Iteration 88 - Learning Rate: 0.0009978784404692837
# Iteration 89, Loss: 3.6314640045166016
# Iteration 89 - Learning Rate: 0.0009978299843512199
# Iteration 90, Loss: 3.5051589012145996
# Iteration 90 - Learning Rate: 0.000997780982301539
# Iteration 91, Loss: 3.3012332916259766
# Iteration 91 - Learning Rate: 0.0009977314343739773
# Iteration 92, Loss: 3.2495477199554443
# Iteration 92 - Learning Rate: 0.0009976813406228709
# Iteration 93, Loss: 3.3553121089935303
# Iteration 93 - Learning Rate: 0.0009976307011031532
# Iteration 94, Loss: 3.507478713989258
# Iteration 94 - Learning Rate: 0.0009975795158703566
# Iteration 95, Loss: 3.3735604286193848
# Iteration 95 - Learning Rate: 0.0009975277849806124
# Iteration 96, Loss: 3.442028760910034
# Iteration 96 - Learning Rate: 0.0009974755084906494
# Iteration 97, Loss: 3.62721586227417
# Iteration 97 - Learning Rate: 0.0009974226864577953
# Iteration 98, Loss: 3.5010383129119873
# Iteration 98 - Learning Rate: 0.000997369318939976
# Iteration 99, Loss: 3.356663227081299
# Iteration 99 - Learning Rate: 0.0009973154059957155
# Iteration 100, Loss: 3.426570415496826
# Iteration 100 - Learning Rate: 0.000997260947684136
# Iteration 101, Loss: 3.4993908405303955
# Iteration 101 - Learning Rate: 0.0009972059440649576
# Iteration 102, Loss: 3.1603474617004395
# Iteration 102 - Learning Rate: 0.0009971503951984987
# Iteration 103, Loss: 3.535414695739746
# Iteration 103 - Learning Rate: 0.0009970943011456753
# Iteration 104, Loss: 3.5012316703796387
# Iteration 104 - Learning Rate: 0.0009970376619680016
# Iteration 105, Loss: 3.037898063659668
# Iteration 105 - Learning Rate: 0.0009969804777275892
# Iteration 106, Loss: 3.3091530799865723
# Iteration 106 - Learning Rate: 0.0009969227484871476
# Iteration 107, Loss: 3.2060256004333496
# Iteration 107 - Learning Rate: 0.000996864474309984
# Iteration 108, Loss: 3.1712217330932617
# Iteration 108 - Learning Rate: 0.0009968056552600033
# Iteration 109, Loss: 3.6004393100738525
# Iteration 109 - Learning Rate: 0.0009967462914017078
# Iteration 110, Loss: 3.1227657794952393
# Iteration 110 - Learning Rate: 0.0009966863828001975
# Iteration 111, Loss: 3.5902576446533203
# Iteration 111 - Learning Rate: 0.000996625929521169
# Iteration 112, Loss: 3.213869094848633
# Iteration 112 - Learning Rate: 0.0009965649316309169
# Iteration 113, Loss: 3.1156110763549805
# Iteration 113 - Learning Rate: 0.0009965033891963329
# Iteration 114, Loss: 3.366454601287842
# Iteration 114 - Learning Rate: 0.000996441302284906
# Iteration 115, Loss: 3.3507704734802246
# Iteration 115 - Learning Rate: 0.000996378670964722
# Iteration 116, Loss: 3.1416330337524414
# Iteration 116 - Learning Rate: 0.0009963154953044637
# Iteration 117, Loss: 3.2625272274017334
# Iteration 117 - Learning Rate: 0.0009962517753734112
# Iteration 118, Loss: 3.2704057693481445
# Iteration 118 - Learning Rate: 0.0009961875112414408
# Iteration 119, Loss: 3.518545627593994
# Iteration 119 - Learning Rate: 0.0009961227029790264
# Iteration 120, Loss: 3.4483487606048584
# Iteration 120 - Learning Rate: 0.0009960573506572383
# Iteration 121, Loss: 3.1226072311401367
# Iteration 121 - Learning Rate: 0.000995991454347743
# Iteration 122, Loss: 3.1415882110595703
# Iteration 122 - Learning Rate: 0.000995925014122804
# Iteration 123, Loss: 3.2641799449920654
# Iteration 123 - Learning Rate: 0.000995858030055281
# Iteration 124, Loss: 3.1447877883911133
# Iteration 124 - Learning Rate: 0.0009957905022186305
# Iteration 125, Loss: 3.1233277320861816
# Iteration 125 - Learning Rate: 0.0009957224306869049
# Iteration 126, Loss: 3.334286689758301
# Iteration 126 - Learning Rate: 0.000995653815534753
# Iteration 127, Loss: 3.1933844089508057
# Iteration 127 - Learning Rate: 0.0009955846568374198
# Iteration 128, Loss: 3.2140626907348633
# Iteration 128 - Learning Rate: 0.0009955149546707462
# Iteration 129, Loss: 3.291166305541992
# Iteration 129 - Learning Rate: 0.0009954447091111691
# Iteration 130, Loss: 3.3226540088653564
# Iteration 130 - Learning Rate: 0.0009953739202357215
# Iteration 131, Loss: 2.9703710079193115
# Iteration 131 - Learning Rate: 0.0009953025881220322
# Iteration 132, Loss: 3.1942262649536133
# Iteration 132 - Learning Rate: 0.0009952307128483252
# Iteration 133, Loss: 3.0825819969177246
# Iteration 133 - Learning Rate: 0.000995158294493421
# Iteration 134, Loss: 3.0851006507873535
# Iteration 134 - Learning Rate: 0.0009950853331367351
# Iteration 135, Loss: 7.378407955169678
# Iteration 135 - Learning Rate: 0.0009950118288582783
# Iteration 136, Loss: 3.1229023933410645
# Iteration 136 - Learning Rate: 0.0009949377817386573
# Iteration 137, Loss: 173.3021697998047
# Iteration 137 - Learning Rate: 0.000994863191859074
# Iteration 138, Loss: 4.405076503753662
# Iteration 138 - Learning Rate: 0.0009947880593013248
# Iteration 139, Loss: 3.0712366104125977
# Iteration 139 - Learning Rate: 0.0009947123841478026
# Iteration 140, Loss: 124.0674057006836
# Iteration 140 - Learning Rate: 0.0009946361664814937
# Iteration 141, Loss: 223.30921936035156
# Iteration 141 - Learning Rate: 0.0009945594063859803
# Iteration 142, Loss: 3.4869818687438965
# Iteration 142 - Learning Rate: 0.0009944821039454396
# Iteration 143, Loss: 270.3106994628906
# Iteration 143 - Learning Rate: 0.0009944042592446428
# Iteration 144, Loss: 99.53591918945312
# Iteration 144 - Learning Rate: 0.0009943258723689565
# Iteration 145, Loss: 258.7842712402344
# Iteration 145 - Learning Rate: 0.0009942469434043413
# Iteration 146, Loss: 292.23980712890625
# Iteration 146 - Learning Rate: 0.0009941674724373527
# Iteration 147, Loss: 66.92897033691406
# Iteration 147 - Learning Rate: 0.00099408745955514
# Iteration 148, Loss: 129.1320343017578
# Iteration 148 - Learning Rate: 0.0009940069048454472
# Iteration 149, Loss: 289.8454284667969
# Iteration 149 - Learning Rate: 0.0009939258083966126
# Iteration 150, Loss: 175.60223388671875
# Iteration 150 - Learning Rate: 0.0009938441702975684
# Iteration 151, Loss: 190.4847412109375
# Iteration 151 - Learning Rate: 0.0009937619906378408
# Iteration 152, Loss: 187.62986755371094
# Iteration 152 - Learning Rate: 0.0009936792695075499
# Iteration 153, Loss: 261.4040222167969
# Iteration 153 - Learning Rate: 0.0009935960069974092
# Iteration 154, Loss: 571.4681396484375
# Iteration 154 - Learning Rate: 0.0009935122031987265
# Iteration 155, Loss: 494.9937438964844
# Iteration 155 - Learning Rate: 0.0009934278582034032
# Iteration 156, Loss: 276.14556884765625
# Iteration 156 - Learning Rate: 0.0009933429721039335
# Iteration 157, Loss: 223.4578094482422
# Iteration 157 - Learning Rate: 0.0009932575449934059
# Iteration 158, Loss: 116.99178314208984
# Iteration 158 - Learning Rate: 0.0009931715769655011
# Iteration 159, Loss: 3.093714475631714
# Iteration 159 - Learning Rate: 0.0009930850681144942
# Iteration 160, Loss: 181.31085205078125
# Iteration 160 - Learning Rate: 0.0009929980185352523
# Iteration 161, Loss: 61.816776275634766
# Iteration 161 - Learning Rate: 0.0009929104283232359
# Iteration 162, Loss: 4.238347053527832
# Iteration 162 - Learning Rate: 0.0009928222975744987
# Iteration 163, Loss: 61.21068572998047
# Iteration 163 - Learning Rate: 0.0009927336263856868
# Iteration 164, Loss: 3.121211528778076
# Iteration 164 - Learning Rate: 0.000992644414854039
# Iteration 165, Loss: 59.54287338256836
# Iteration 165 - Learning Rate: 0.0009925546630773865
# Iteration 166, Loss: 3.0394978523254395
# Iteration 166 - Learning Rate: 0.0009924643711541534
# Iteration 167, Loss: 3.109930992126465
# Iteration 167 - Learning Rate: 0.000992373539183356
# Iteration 168, Loss: 3.1219840049743652
# Iteration 168 - Learning Rate: 0.0009922821672646023
# Iteration 169, Loss: 59.4715461730957
# Iteration 169 - Learning Rate: 0.000992190255498093
# Iteration 170, Loss: 58.68882369995117
# Iteration 170 - Learning Rate: 0.0009920978039846204
# Iteration 171, Loss: 3.0149831771850586
# Iteration 171 - Learning Rate: 0.0009920048128255693
# Iteration 172, Loss: 4.11397647857666
# Iteration 172 - Learning Rate: 0.0009919112821229158
# Iteration 173, Loss: 3.0695226192474365
# Iteration 173 - Learning Rate: 0.0009918172119792274
# Iteration 174, Loss: 93.86609649658203
# Iteration 174 - Learning Rate: 0.0009917226024976642
# Iteration 175, Loss: 3.256713390350342
# Iteration 175 - Learning Rate: 0.0009916274537819765
# Iteration 176, Loss: 49.8190803527832
# Iteration 176 - Learning Rate: 0.0009915317659365069
# Iteration 177, Loss: 3.594358205795288
# Iteration 177 - Learning Rate: 0.0009914355390661885
# Iteration 178, Loss: 2.944532871246338
# Iteration 178 - Learning Rate: 0.0009913387732765466
# Iteration 179, Loss: 46.61555099487305
# Iteration 179 - Learning Rate: 0.0009912414686736961
# Iteration 180, Loss: 11.73129653930664
# Iteration 180 - Learning Rate: 0.0009911436253643435
# Iteration 181, Loss: 3.211810350418091
# Iteration 181 - Learning Rate: 0.000991045243455786
# Iteration 182, Loss: 3.0344295501708984
# Iteration 182 - Learning Rate: 0.0009909463230559116
# Iteration 183, Loss: 42.17434310913086
# Iteration 183 - Learning Rate: 0.0009908468642731985
# Iteration 184, Loss: 3.0859570503234863
# Iteration 184 - Learning Rate: 0.0009907468672167156
# Iteration 185, Loss: 88.98162078857422
# Iteration 185 - Learning Rate: 0.0009906463319961218
# Iteration 186, Loss: 80.51211547851562
# Iteration 186 - Learning Rate: 0.0009905452587216663
# Iteration 187, Loss: 38.082183837890625
# Iteration 187 - Learning Rate: 0.0009904436475041884
# Iteration 188, Loss: 151.39222717285156
# Iteration 188 - Learning Rate: 0.000990341498455117
# Iteration 189, Loss: 38.098697662353516
# Iteration 189 - Learning Rate: 0.0009902388116864716
# Iteration 190, Loss: 36.08151626586914
# Iteration 190 - Learning Rate: 0.0009901355873108602
# Iteration 191, Loss: 34.90494155883789
# Iteration 191 - Learning Rate: 0.0009900318254414814
# Iteration 192, Loss: 3.0106513500213623
# Iteration 192 - Learning Rate: 0.0009899275261921227
# Iteration 193, Loss: 72.59078979492188
# Iteration 193 - Learning Rate: 0.000989822689677161
# Iteration 194, Loss: 30.198299407958984
# Iteration 194 - Learning Rate: 0.0009897173160115624
# Iteration 195, Loss: 121.3627700805664
# Iteration 195 - Learning Rate: 0.0009896114053108821
# Iteration 196, Loss: 28.199668884277344
# Iteration 196 - Learning Rate: 0.0009895049576912642
# Iteration 197, Loss: 27.221017837524414
# Iteration 197 - Learning Rate: 0.0009893979732694413
# Iteration 198, Loss: 3.1114344596862793
# Iteration 198 - Learning Rate: 0.0009892904521627353
# Iteration 199, Loss: 48.59702682495117
# Iteration 199 - Learning Rate: 0.0009891823944890561
# Iteration 200, Loss: 2.937732458114624
# Iteration 200 - Learning Rate: 0.0009890738003669021
# Iteration 201, Loss: 143.42251586914062
# Iteration 201 - Learning Rate: 0.0009889646699153601
# Iteration 202, Loss: 45.2276496887207
# Iteration 202 - Learning Rate: 0.0009888550032541052
# Iteration 203, Loss: 46.4908447265625
# Iteration 203 - Learning Rate: 0.0009887448005034003
# Iteration 204, Loss: 51.431678771972656
# Iteration 204 - Learning Rate: 0.000988634061784096
# Iteration 205, Loss: 58.983909606933594
# Iteration 205 - Learning Rate: 0.000988522787217631
# Iteration 206, Loss: 34.926937103271484
# Iteration 206 - Learning Rate: 0.0009884109769260315
# Iteration 207, Loss: 51.54158020019531
# Iteration 207 - Learning Rate: 0.0009882986310319113
# Iteration 208, Loss: 24.65883445739746
# Iteration 208 - Learning Rate: 0.0009881857496584715
# Iteration 209, Loss: 3.099877119064331
# Iteration 209 - Learning Rate: 0.0009880723329295002
# Iteration 210, Loss: 3.238964796066284
# Iteration 210 - Learning Rate: 0.0009879583809693727
# Iteration 211, Loss: 3.155991315841675
# Iteration 211 - Learning Rate: 0.0009878438939030514
# Iteration 212, Loss: 3.4058456420898438
# Iteration 212 - Learning Rate: 0.0009877288718560856
# Iteration 213, Loss: 3.1162285804748535
# Iteration 213 - Learning Rate: 0.0009876133149546106
# Iteration 214, Loss: 3.2051773071289062
# Iteration 214 - Learning Rate: 0.0009874972233253493
# Iteration 215, Loss: 9.372322082519531
# Iteration 215 - Learning Rate: 0.0009873805970956099
# Iteration 216, Loss: 6.0304365158081055
# Iteration 216 - Learning Rate: 0.0009872634363932876
# Iteration 217, Loss: 3.2248706817626953
# Iteration 217 - Learning Rate: 0.0009871457413468633
# Iteration 218, Loss: 3.3761229515075684
# Iteration 218 - Learning Rate: 0.0009870275120854044
# Iteration 219, Loss: 39.02949142456055
# Iteration 219 - Learning Rate: 0.0009869087487385634
# Iteration 220, Loss: 3.1442883014678955
# Iteration 220 - Learning Rate: 0.0009867894514365792
# Iteration 221, Loss: 3.244210720062256
# Iteration 221 - Learning Rate: 0.0009866696203102755
# Iteration 222, Loss: 3.2302048206329346
# Iteration 222 - Learning Rate: 0.0009865492554910623
# Iteration 223, Loss: 14.41459846496582
# Iteration 223 - Learning Rate: 0.000986428357110934
# Iteration 224, Loss: 47.11589050292969
# Iteration 224 - Learning Rate: 0.0009863069253024707
# Iteration 225, Loss: 3.4380271434783936
# Iteration 225 - Learning Rate: 0.0009861849601988373
# Iteration 226, Loss: 3.016540050506592
# Iteration 226 - Learning Rate: 0.0009860624619337833
# Iteration 227, Loss: 3.230039119720459
# Iteration 227 - Learning Rate: 0.0009859394306416431
# Iteration 228, Loss: 3.2224783897399902
# Iteration 228 - Learning Rate: 0.000985815866457336
# Iteration 229, Loss: 3.233276844024658
# Iteration 229 - Learning Rate: 0.0009856917695163646
# Iteration 230, Loss: 3.237849712371826
# Iteration 230 - Learning Rate: 0.000985567139954817
# Iteration 231, Loss: 112.31185913085938
# Iteration 231 - Learning Rate: 0.0009854419779093645
# Iteration 232, Loss: 22.39753532409668
# Iteration 232 - Learning Rate: 0.0009853162835172626
# Iteration 233, Loss: 104.75361633300781
# Iteration 233 - Learning Rate: 0.000985190056916351
# Iteration 234, Loss: 24.6867733001709
# Iteration 234 - Learning Rate: 0.000985063298245052
# Iteration 235, Loss: 21.857059478759766
# Iteration 235 - Learning Rate: 0.0009849360076423725
# Iteration 236, Loss: 3.210653781890869
# Iteration 236 - Learning Rate: 0.000984808185247902
# Iteration 237, Loss: 3.1153674125671387
# Iteration 237 - Learning Rate: 0.0009846798312018138
# Iteration 238, Loss: 20.720346450805664
# Iteration 238 - Learning Rate: 0.0009845509456448635
# Iteration 239, Loss: 21.98348617553711
# Iteration 239 - Learning Rate: 0.0009844215287183901
# Iteration 240, Loss: 38.602108001708984
# Iteration 240 - Learning Rate: 0.000984291580564315
# Iteration 241, Loss: 26.76673126220703
# Iteration 241 - Learning Rate: 0.0009841611013251422
# Iteration 242, Loss: 25.487295150756836
# Iteration 242 - Learning Rate: 0.0009840300911439584
# Iteration 243, Loss: 3.1719422340393066
# Iteration 243 - Learning Rate: 0.0009838985501644322
# Iteration 244, Loss: 3.1794872283935547
# Iteration 244 - Learning Rate: 0.0009837664785308144
# Iteration 245, Loss: 3.1166696548461914
# Iteration 245 - Learning Rate: 0.000983633876387938
# Iteration 246, Loss: 40.22563934326172
# Iteration 246 - Learning Rate: 0.000983500743881217
# Iteration 247, Loss: 3.1745376586914062
# Iteration 247 - Learning Rate: 0.000983367081156648
# Iteration 248, Loss: 3.031789779663086
# Iteration 248 - Learning Rate: 0.0009832328883608084
# Iteration 249, Loss: 19.564990997314453
# Iteration 249 - Learning Rate: 0.000983098165640857
# Iteration 250, Loss: 21.373680114746094
# Iteration 250 - Learning Rate: 0.0009829629131445337
# Iteration 251, Loss: 2.985729217529297
# Iteration 251 - Learning Rate: 0.0009828271310201597
# Iteration 252, Loss: 3.291428565979004
# Iteration 252 - Learning Rate: 0.0009826908194166366
# Iteration 253, Loss: 67.79219055175781
# Iteration 253 - Learning Rate: 0.0009825539784834468
# Iteration 254, Loss: 3.3857531547546387
# Iteration 254 - Learning Rate: 0.000982416608370653
# Iteration 255, Loss: 3.0218558311462402
# Iteration 255 - Learning Rate: 0.0009822787092288985
# Iteration 256, Loss: 2.9859023094177246
# Iteration 256 - Learning Rate: 0.000982140281209407
# Iteration 257, Loss: 87.90611267089844
# Iteration 257 - Learning Rate: 0.0009820013244639812
# Iteration 258, Loss: 23.564760208129883
# Iteration 258 - Learning Rate: 0.0009818618391450047
# Iteration 259, Loss: 22.69805335998535
# Iteration 259 - Learning Rate: 0.0009817218254054398
# Iteration 260, Loss: 59.644012451171875
# Iteration 260 - Learning Rate: 0.000981581283398829
# Iteration 261, Loss: 3.1066150665283203
# Iteration 261 - Learning Rate: 0.0009814402132792938
# Iteration 262, Loss: 8.007304191589355
# Iteration 262 - Learning Rate: 0.000981298615201535
# Iteration 263, Loss: 3.5676803588867188
# Iteration 263 - Learning Rate: 0.0009811564893208316
# Iteration 264, Loss: 40.31459426879883
# Iteration 264 - Learning Rate: 0.0009810138357930428
# Iteration 265, Loss: 7.7371931076049805
# Iteration 265 - Learning Rate: 0.0009808706547746056
# Iteration 266, Loss: 3.230893135070801
# Iteration 266 - Learning Rate: 0.0009807269464225353
# Iteration 267, Loss: 3.2939798831939697
# Iteration 267 - Learning Rate: 0.0009805827108944258
# Iteration 268, Loss: 30.787153244018555
# Iteration 268 - Learning Rate: 0.0009804379483484493
# Iteration 269, Loss: 29.82259750366211
# Iteration 269 - Learning Rate: 0.0009802926589433552
# Iteration 270, Loss: 3.1970109939575195
# Iteration 270 - Learning Rate: 0.0009801468428384714
# Iteration 271, Loss: 3.2498059272766113
# Iteration 271 - Learning Rate: 0.0009800005001937033
# Iteration 272, Loss: 3.125034809112549
# Iteration 272 - Learning Rate: 0.0009798536311695332
# Iteration 273, Loss: 29.150062561035156
# Iteration 273 - Learning Rate: 0.0009797062359270213
# Iteration 274, Loss: 3.1624362468719482
# Iteration 274 - Learning Rate: 0.0009795583146278044
# Iteration 275, Loss: 3.3678035736083984
# Iteration 275 - Learning Rate: 0.0009794098674340964
# Iteration 276, Loss: 3.210068702697754
# Iteration 276 - Learning Rate: 0.0009792608945086879
# Iteration 277, Loss: 2.987475633621216
# Iteration 277 - Learning Rate: 0.0009791113960149456
# Iteration 278, Loss: 3.1888742446899414
# Iteration 278 - Learning Rate: 0.0009789613721168137
# Iteration 279, Loss: 3.297495126724243
# Iteration 279 - Learning Rate: 0.0009788108229788108
# Iteration 280, Loss: 3.156069278717041
# Iteration 280 - Learning Rate: 0.0009786597487660333
# Iteration 281, Loss: 3.2331888675689697
# Iteration 281 - Learning Rate: 0.0009785081496441524
# Iteration 282, Loss: 53.221519470214844
# Iteration 282 - Learning Rate: 0.000978356025779415
# Iteration 283, Loss: 2.9869542121887207
# Iteration 283 - Learning Rate: 0.0009782033773386434
# Iteration 284, Loss: 3.227318286895752
# Iteration 284 - Learning Rate: 0.0009780502044892357
# Iteration 285, Loss: 75.6142578125
# Iteration 285 - Learning Rate: 0.0009778965073991646
# Iteration 286, Loss: 4.013936996459961
# Iteration 286 - Learning Rate: 0.0009777422862369779
# Iteration 287, Loss: 3.377633571624756
# Iteration 287 - Learning Rate: 0.0009775875411717977
# Iteration 288, Loss: 3.208796739578247
# Iteration 288 - Learning Rate: 0.0009774322723733212
# Iteration 289, Loss: 2.966622829437256
# Iteration 289 - Learning Rate: 0.0009772764800118196
# Iteration 290, Loss: 3.0409600734710693
# Iteration 290 - Learning Rate: 0.000977120164258138
# Iteration 291, Loss: 3.0686774253845215
# Iteration 291 - Learning Rate: 0.0009769633252836964
# Iteration 292, Loss: 3.096005916595459
# Iteration 292 - Learning Rate: 0.0009768059632604875
# Iteration 293, Loss: 6.760514736175537
# Iteration 293 - Learning Rate: 0.0009766480783610784
# Iteration 294, Loss: 3.1566052436828613
# Iteration 294 - Learning Rate: 0.000976489670758609
# Iteration 295, Loss: 2.7883481979370117
# Iteration 295 - Learning Rate: 0.0009763307406267927
# Iteration 296, Loss: 3.1387381553649902
# Iteration 296 - Learning Rate: 0.0009761712881399159
# Iteration 297, Loss: 3.2393078804016113
# Iteration 297 - Learning Rate: 0.0009760113134728378
# Iteration 298, Loss: 3.021639585494995
# Iteration 298 - Learning Rate: 0.0009758508168009902
# Iteration 299, Loss: 2.9946937561035156
# Iteration 299 - Learning Rate: 0.0009756897983003776
# Iteration 300, Loss: 3.197524070739746
# Iteration 300 - Learning Rate: 0.0009755282581475764
# Iteration 301, Loss: 3.184971570968628
# Iteration 301 - Learning Rate: 0.0009753661965197348
# Iteration 302, Loss: 2.8329906463623047
# Iteration 302 - Learning Rate: 0.0009752036135945738
# Iteration 303, Loss: 3.0329232215881348
# Iteration 303 - Learning Rate: 0.0009750405095503853
# Iteration 304, Loss: 3.176797389984131
# Iteration 304 - Learning Rate: 0.0009748768845660329
# Iteration 305, Loss: 3.0531527996063232
# Iteration 305 - Learning Rate: 0.0009747127388209514
# Iteration 306, Loss: 42.787811279296875
# Iteration 306 - Learning Rate: 0.0009745480724951467
# Iteration 307, Loss: 2.9766151905059814
# Iteration 307 - Learning Rate: 0.0009743828857691956
# Iteration 308, Loss: 26.09585189819336
# Iteration 308 - Learning Rate: 0.000974217178824246
# Iteration 309, Loss: 2.9851784706115723
# Iteration 309 - Learning Rate: 0.0009740509518420153
# Iteration 310, Loss: 2.969346046447754
# Iteration 310 - Learning Rate: 0.0009738842050047923
# Iteration 311, Loss: 3.245539903640747
# Iteration 311 - Learning Rate: 0.0009737169384954348
# Iteration 312, Loss: 3.4299352169036865
# Iteration 312 - Learning Rate: 0.0009735491524973715
# Iteration 313, Loss: 3.222461700439453
# Iteration 313 - Learning Rate: 0.0009733808471946001
# Iteration 314, Loss: 3.3062243461608887
# Iteration 314 - Learning Rate: 0.000973212022771688
# Iteration 315, Loss: 3.0499491691589355
# Iteration 315 - Learning Rate: 0.0009730426794137719
# Iteration 316, Loss: 3.0796194076538086
# Iteration 316 - Learning Rate: 0.0009728728173065576
# Iteration 317, Loss: 3.120971202850342
# Iteration 317 - Learning Rate: 0.0009727024366363199
# Iteration 318, Loss: 3.0768685340881348
# Iteration 318 - Learning Rate: 0.0009725315375899016
# Iteration 319, Loss: 2.9896745681762695
# Iteration 319 - Learning Rate: 0.000972360120354715
# Iteration 320, Loss: 3.1158196926116943
# Iteration 320 - Learning Rate: 0.0009721881851187399
# Iteration 321, Loss: 2.9917635917663574
# Iteration 321 - Learning Rate: 0.0009720157320705242
# Iteration 322, Loss: 3.2159905433654785
# Iteration 322 - Learning Rate: 0.0009718427613991839
# Iteration 323, Loss: 2.9594385623931885
# Iteration 323 - Learning Rate: 0.0009716692732944027
# Iteration 324, Loss: 3.15310001373291
# Iteration 324 - Learning Rate: 0.0009714952679464315
# Iteration 325, Loss: 2.9859237670898438
# Iteration 325 - Learning Rate: 0.0009713207455460884
# Iteration 326, Loss: 3.0605640411376953
# Iteration 326 - Learning Rate: 0.0009711457062847586
# Iteration 327, Loss: 7.865978240966797
# Iteration 327 - Learning Rate: 0.0009709701503543944
# Iteration 328, Loss: 5.821523666381836
# Iteration 328 - Learning Rate: 0.0009707940779475143
# Iteration 329, Loss: 3.0244805812835693
# Iteration 329 - Learning Rate: 0.0009706174892572031
# Iteration 330, Loss: 3.0961976051330566
# Iteration 330 - Learning Rate: 0.0009704403844771122
# Iteration 331, Loss: 3.1154370307922363
# Iteration 331 - Learning Rate: 0.0009702627638014583
# Iteration 332, Loss: 37.87480163574219
# Iteration 332 - Learning Rate: 0.0009700846274250244
# Iteration 333, Loss: 2.985856056213379
# Iteration 333 - Learning Rate: 0.0009699059755431592
# Iteration 334, Loss: 2.865738868713379
# Iteration 334 - Learning Rate: 0.0009697268083517761
# Iteration 335, Loss: 2.9678783416748047
# Iteration 335 - Learning Rate: 0.0009695471260473538
# Iteration 336, Loss: 3.1676268577575684
# Iteration 336 - Learning Rate: 0.0009693669288269365
# Iteration 337, Loss: 3.362724781036377
# Iteration 337 - Learning Rate: 0.0009691862168881319
# Iteration 338, Loss: 3.2536771297454834
# Iteration 338 - Learning Rate: 0.0009690049904291134
# Iteration 339, Loss: 3.078583002090454
# Iteration 339 - Learning Rate: 0.0009688232496486174
# Iteration 340, Loss: 4.845886707305908
# Iteration 340 - Learning Rate: 0.0009686409947459453
# Iteration 341, Loss: 3.882169723510742
# Iteration 341 - Learning Rate: 0.000968458225920962
# Iteration 342, Loss: 3.0750176906585693
# Iteration 342 - Learning Rate: 0.0009682749433740958
# Iteration 343, Loss: 2.9192662239074707
# Iteration 343 - Learning Rate: 0.0009680911473063385
# Iteration 344, Loss: 2.9024155139923096
# Iteration 344 - Learning Rate: 0.000967906837919245
# Iteration 345, Loss: 3.2247867584228516
# Iteration 345 - Learning Rate: 0.0009677220154149332
# Iteration 346, Loss: 2.97837233543396
# Iteration 346 - Learning Rate: 0.0009675366799960835
# Iteration 347, Loss: 3.122429847717285
# Iteration 347 - Learning Rate: 0.0009673508318659393
# Iteration 348, Loss: 3.064274311065674
# Iteration 348 - Learning Rate: 0.0009671644712283055
# Iteration 349, Loss: 2.828855514526367
# Iteration 349 - Learning Rate: 0.0009669775982875494
# Iteration 350, Loss: 3.1610937118530273
# Iteration 350 - Learning Rate: 0.0009667902132486002
# Iteration 351, Loss: 5.634885311126709
# Iteration 351 - Learning Rate: 0.0009666023163169487
# Iteration 352, Loss: 2.8628451824188232
# Iteration 352 - Learning Rate: 0.0009664139076986468
# Iteration 353, Loss: 3.04740571975708
# Iteration 353 - Learning Rate: 0.0009662249876003074
# Iteration 354, Loss: 4.884754180908203
# Iteration 354 - Learning Rate: 0.0009660355562291048
# Iteration 355, Loss: 2.9824156761169434
# Iteration 355 - Learning Rate: 0.0009658456137927739
# Iteration 356, Loss: 5.618385314941406
# Iteration 356 - Learning Rate: 0.0009656551604996096
# Iteration 357, Loss: 3.4141345024108887
# Iteration 357 - Learning Rate: 0.0009654641965584673
# Iteration 358, Loss: 2.8803110122680664
# Iteration 358 - Learning Rate: 0.0009652727221787625
# Iteration 359, Loss: 2.902172803878784
# Iteration 359 - Learning Rate: 0.0009650807375704703
# Iteration 360, Loss: 3.367619037628174
# Iteration 360 - Learning Rate: 0.0009648882429441252
# Iteration 361, Loss: 8.212196350097656
# Iteration 361 - Learning Rate: 0.0009646952385108213
# Iteration 362, Loss: 43.37279510498047
# Iteration 362 - Learning Rate: 0.0009645017244822118
# Iteration 363, Loss: 41.74565124511719
# Iteration 363 - Learning Rate: 0.0009643077010705083
# Iteration 364, Loss: 2.904226303100586
# Iteration 364 - Learning Rate: 0.0009641131684884811
# Iteration 365, Loss: 3.356692314147949
# Iteration 365 - Learning Rate: 0.0009639181269494595
# Iteration 366, Loss: 3.3247787952423096
# Iteration 366 - Learning Rate: 0.0009637225766673303
# Iteration 367, Loss: 3.0840249061584473
# Iteration 367 - Learning Rate: 0.0009635265178565382
# Iteration 368, Loss: 2.8431549072265625
# Iteration 368 - Learning Rate: 0.0009633299507320857
# Iteration 369, Loss: 3.1612675189971924
# Iteration 369 - Learning Rate: 0.0009631328755095329
# Iteration 370, Loss: 3.0323877334594727
# Iteration 370 - Learning Rate: 0.000962935292404997
# Iteration 371, Loss: 3.6572909355163574
# Iteration 371 - Learning Rate: 0.0009627372016351519
# Iteration 372, Loss: 3.284684181213379
# Iteration 372 - Learning Rate: 0.0009625386034172286
# Iteration 373, Loss: 3.026430368423462
# Iteration 373 - Learning Rate: 0.0009623394979690144
# Iteration 374, Loss: 3.2231500148773193
# Iteration 374 - Learning Rate: 0.0009621398855088526
# Iteration 375, Loss: 3.3586931228637695
# Iteration 375 - Learning Rate: 0.000961939766255643
# Iteration 376, Loss: 2.987617254257202
# Iteration 376 - Learning Rate: 0.0009617391404288407
# Iteration 377, Loss: 2.960481882095337
# Iteration 377 - Learning Rate: 0.0009615380082484568
# Iteration 378, Loss: 2.9548778533935547
# Iteration 378 - Learning Rate: 0.000961336369935057
# Iteration 379, Loss: 3.085793972015381
# Iteration 379 - Learning Rate: 0.0009611342257097627
# Iteration 380, Loss: 5.256098747253418
# Iteration 380 - Learning Rate: 0.0009609315757942499
# Iteration 381, Loss: 3.315397262573242
# Iteration 381 - Learning Rate: 0.0009607284204107489
# Iteration 382, Loss: 3.1898646354675293
# Iteration 382 - Learning Rate: 0.0009605247597820444
# Iteration 383, Loss: 3.0870461463928223
# Iteration 383 - Learning Rate: 0.0009603205941314755
# Iteration 384, Loss: 3.158606767654419
# Iteration 384 - Learning Rate: 0.0009601159236829349
# Iteration 385, Loss: 3.1262893676757812
# Iteration 385 - Learning Rate: 0.0009599107486608686
# Iteration 386, Loss: 3.047185182571411
# Iteration 386 - Learning Rate: 0.0009597050692902761
# Iteration 387, Loss: 2.9233200550079346
# Iteration 387 - Learning Rate: 0.0009594988857967103
# Iteration 388, Loss: 2.8598742485046387
# Iteration 388 - Learning Rate: 0.0009592921984062767
# Iteration 389, Loss: 3.0943005084991455
# Iteration 389 - Learning Rate: 0.0009590850073456333
# Iteration 390, Loss: 3.0506420135498047
# Iteration 390 - Learning Rate: 0.0009588773128419903
# Iteration 391, Loss: 3.326690673828125
# Iteration 391 - Learning Rate: 0.0009586691151231105
# Iteration 392, Loss: 7.816503524780273
# Iteration 392 - Learning Rate: 0.0009584604144173079
# Iteration 393, Loss: 3.0769033432006836
# Iteration 393 - Learning Rate: 0.0009582512109534487
# Iteration 394, Loss: 3.0197505950927734
# Iteration 394 - Learning Rate: 0.00095804150496095
# Iteration 395, Loss: 3.171187400817871
# Iteration 395 - Learning Rate: 0.0009578312966697802
# Iteration 396, Loss: 3.0071470737457275
# Iteration 396 - Learning Rate: 0.0009576205863104584
# Iteration 397, Loss: 3.0929746627807617
# Iteration 397 - Learning Rate: 0.0009574093741140544
# Iteration 398, Loss: 3.1507039070129395
# Iteration 398 - Learning Rate: 0.0009571976603121883
# Iteration 399, Loss: 2.9460887908935547
# Iteration 399 - Learning Rate: 0.00095698544513703
# Iteration 400, Loss: 3.435757637023926
# Iteration 400 - Learning Rate: 0.0009567727288212999
# Iteration 401, Loss: 2.857391119003296
# Iteration 401 - Learning Rate: 0.0009565595115982674
# Iteration 402, Loss: 2.6953189373016357
# Iteration 402 - Learning Rate: 0.000956345793701751
# Iteration 403, Loss: 5.471238136291504
# Iteration 403 - Learning Rate: 0.0009561315753661188
# Iteration 404, Loss: 5.362207889556885
# Iteration 404 - Learning Rate: 0.0009559168568262876
# Iteration 405, Loss: 2.7904913425445557
# Iteration 405 - Learning Rate: 0.0009557016383177222
# Iteration 406, Loss: 3.105360984802246
# Iteration 406 - Learning Rate: 0.0009554859200764366
# Iteration 407, Loss: 50.645870208740234
# Iteration 407 - Learning Rate: 0.0009552697023389919
# Iteration 408, Loss: 3.034695863723755
# Iteration 408 - Learning Rate: 0.0009550529853424974
# Iteration 409, Loss: 3.089529037475586
# Iteration 409 - Learning Rate: 0.0009548357693246102
# Iteration 410, Loss: 3.0064454078674316
# Iteration 410 - Learning Rate: 0.000954618054523534
# Iteration 411, Loss: 3.22601056098938
# Iteration 411 - Learning Rate: 0.0009543998411780198
# Iteration 412, Loss: 3.0447258949279785
# Iteration 412 - Learning Rate: 0.0009541811295273653
# Iteration 413, Loss: 3.7974581718444824
# Iteration 413 - Learning Rate: 0.0009539619198114147
# Iteration 414, Loss: 2.722135543823242
# Iteration 414 - Learning Rate: 0.0009537422122705584
# Iteration 415, Loss: 3.034888505935669
# Iteration 415 - Learning Rate: 0.0009535220071457323
# Iteration 416, Loss: 2.878546714782715
# Iteration 416 - Learning Rate: 0.0009533013046784187
# Iteration 417, Loss: 2.960819721221924
# Iteration 417 - Learning Rate: 0.0009530801051106448
# Iteration 418, Loss: 2.731879949569702
# Iteration 418 - Learning Rate: 0.000952858408684983
# Iteration 419, Loss: 3.1728005409240723
# Iteration 419 - Learning Rate: 0.0009526362156445505
# Iteration 420, Loss: 3.084498882293701
# Iteration 420 - Learning Rate: 0.0009524135262330096
# Iteration 421, Loss: 3.0209031105041504
# Iteration 421 - Learning Rate: 0.0009521903406945663
# Iteration 422, Loss: 2.778769016265869
# Iteration 422 - Learning Rate: 0.0009519666592739708
# Iteration 423, Loss: 2.985781192779541
# Iteration 423 - Learning Rate: 0.0009517424822165174
# Iteration 424, Loss: 2.8753128051757812
# Iteration 424 - Learning Rate: 0.0009515178097680436
# Iteration 425, Loss: 2.7859458923339844
# Iteration 425 - Learning Rate: 0.0009512926421749303
# Iteration 426, Loss: 2.8728721141815186
# Iteration 426 - Learning Rate: 0.0009510669796841013
# Iteration 427, Loss: 2.6960461139678955
# Iteration 427 - Learning Rate: 0.0009508408225430234
# Iteration 428, Loss: 3.1080102920532227
# Iteration 428 - Learning Rate: 0.0009506141709997056
# Iteration 429, Loss: 2.6535441875457764
# Iteration 429 - Learning Rate: 0.000950387025302699
# Iteration 430, Loss: 2.965174674987793
# Iteration 430 - Learning Rate: 0.0009501593857010968
# Iteration 431, Loss: 2.762883186340332
# Iteration 431 - Learning Rate: 0.0009499312524445336
# Iteration 432, Loss: 5.190158843994141
# Iteration 432 - Learning Rate: 0.0009497026257831855
# Iteration 433, Loss: 3.3477537631988525
# Iteration 433 - Learning Rate: 0.0009494735059677698
# Iteration 434, Loss: 2.818174362182617
# Iteration 434 - Learning Rate: 0.0009492438932495443
# Iteration 435, Loss: 7.123638153076172
# Iteration 435 - Learning Rate: 0.0009490137878803077
# Iteration 436, Loss: 2.9182984828948975
# Iteration 436 - Learning Rate: 0.0009487831901123986
# Iteration 437, Loss: 3.0226640701293945
# Iteration 437 - Learning Rate: 0.000948552100198696
# Iteration 438, Loss: 2.914398670196533
# Iteration 438 - Learning Rate: 0.0009483205183926179
# Iteration 439, Loss: 3.294112205505371
# Iteration 439 - Learning Rate: 0.0009480884449481223
# Iteration 440, Loss: 2.9103665351867676
# Iteration 440 - Learning Rate: 0.0009478558801197063
# Iteration 441, Loss: 2.7916312217712402
# Iteration 441 - Learning Rate: 0.0009476228241624057
# Iteration 442, Loss: 2.7645630836486816
# Iteration 442 - Learning Rate: 0.000947389277331795
# Iteration 443, Loss: 2.824859619140625
# Iteration 443 - Learning Rate: 0.0009471552398839868
# Iteration 444, Loss: 4.990297317504883
# Iteration 444 - Learning Rate: 0.0009469207120756318
# Iteration 445, Loss: 2.95601749420166
# Iteration 445 - Learning Rate: 0.0009466856941639188
# Iteration 446, Loss: 2.738142490386963
# Iteration 446 - Learning Rate: 0.0009464501864065734
# Iteration 447, Loss: 3.1646084785461426
# Iteration 447 - Learning Rate: 0.0009462141890618589
# Iteration 448, Loss: 3.0907602310180664
# Iteration 448 - Learning Rate: 0.0009459777023885752
# Iteration 449, Loss: 3.2327356338500977
# Iteration 449 - Learning Rate: 0.0009457407266460592
# Iteration 450, Loss: 2.7584540843963623
# Iteration 450 - Learning Rate: 0.0009455032620941838
# Iteration 451, Loss: 3.045340061187744
# Iteration 451 - Learning Rate: 0.0009452653089933578
# Iteration 452, Loss: 3.250988245010376
# Iteration 452 - Learning Rate: 0.0009450268676045262
# Iteration 453, Loss: 3.1053624153137207
# Iteration 453 - Learning Rate: 0.000944787938189169
# Iteration 454, Loss: 2.8185572624206543
# Iteration 454 - Learning Rate: 0.0009445485210093016
# Iteration 455, Loss: 2.8917455673217773
# Iteration 455 - Learning Rate: 0.0009443086163274743
# Iteration 456, Loss: 3.0696616172790527
# Iteration 456 - Learning Rate: 0.0009440682244067722
# Iteration 457, Loss: 3.070666790008545
# Iteration 457 - Learning Rate: 0.0009438273455108142
# Iteration 458, Loss: 2.8108458518981934
# Iteration 458 - Learning Rate: 0.0009435859799037539
# Iteration 459, Loss: 3.067516803741455
# Iteration 459 - Learning Rate: 0.0009433441278502783
# Iteration 460, Loss: 2.977795124053955
# Iteration 460 - Learning Rate: 0.0009431017896156073
# Iteration 461, Loss: 3.1778316497802734
# Iteration 461 - Learning Rate: 0.000942858965465495
# Iteration 462, Loss: 3.218385696411133
# Iteration 462 - Learning Rate: 0.0009426156556662275
# Iteration 463, Loss: 3.0851998329162598
# Iteration 463 - Learning Rate: 0.0009423718604846242
# Iteration 464, Loss: 2.941126823425293
# Iteration 464 - Learning Rate: 0.0009421275801880361
# Iteration 465, Loss: 3.1967616081237793
# Iteration 465 - Learning Rate: 0.0009418828150443467
# Iteration 466, Loss: 2.9116742610931396
# Iteration 466 - Learning Rate: 0.0009416375653219707
# Iteration 467, Loss: 2.7591657638549805
# Iteration 467 - Learning Rate: 0.000941391831289855
# Iteration 468, Loss: 3.199625015258789
# Iteration 468 - Learning Rate: 0.0009411456132174767
# Iteration 469, Loss: 2.8808798789978027
# Iteration 469 - Learning Rate: 0.0009408989113748441
# Iteration 470, Loss: 3.021599292755127
# Iteration 470 - Learning Rate: 0.0009406517260324962
# Iteration 471, Loss: 2.974641799926758
# Iteration 471 - Learning Rate: 0.0009404040574615019
# Iteration 472, Loss: 2.9940943717956543
# Iteration 472 - Learning Rate: 0.0009401559059334601
# Iteration 473, Loss: 5.378581523895264
# Iteration 473 - Learning Rate: 0.0009399072717204996
# Iteration 474, Loss: 2.9602997303009033
# Iteration 474 - Learning Rate: 0.0009396581550952781
# Iteration 475, Loss: 4.407173156738281
# Iteration 475 - Learning Rate: 0.0009394085563309827
# Iteration 476, Loss: 3.5654654502868652
# Iteration 476 - Learning Rate: 0.000939158475701329
# Iteration 477, Loss: 4.332896709442139
# Iteration 477 - Learning Rate: 0.0009389079134805609
# Iteration 478, Loss: 3.234337329864502
# Iteration 478 - Learning Rate: 0.0009386568699434508
# Iteration 479, Loss: 2.8269548416137695
# Iteration 479 - Learning Rate: 0.0009384053453652985
# Iteration 480, Loss: 2.627323627471924
# Iteration 480 - Learning Rate: 0.0009381533400219318
# Iteration 481, Loss: 3.2074687480926514
# Iteration 481 - Learning Rate: 0.0009379008541897054
# Iteration 482, Loss: 3.108905076980591
# Iteration 482 - Learning Rate: 0.0009376478881455008
# Iteration 483, Loss: 2.6798410415649414
# Iteration 483 - Learning Rate: 0.0009373944421667264
# Iteration 484, Loss: 3.11557936668396
# Iteration 484 - Learning Rate: 0.0009371405165313168
# Iteration 485, Loss: 2.740004539489746
# Iteration 485 - Learning Rate: 0.0009368861115177327
# Iteration 486, Loss: 9.875654220581055
# Iteration 486 - Learning Rate: 0.00093663122740496
# Iteration 487, Loss: 2.6179275512695312
# Iteration 487 - Learning Rate: 0.0009363758644725109
# Iteration 488, Loss: 2.8121962547302246
# Iteration 488 - Learning Rate: 0.0009361200230004218
# Iteration 489, Loss: 2.885798692703247
# Iteration 489 - Learning Rate: 0.0009358637032692545
# Iteration 490, Loss: 3.776946544647217
# Iteration 490 - Learning Rate: 0.0009356069055600948
# Iteration 491, Loss: 2.799254894256592
# Iteration 491 - Learning Rate: 0.0009353496301545529
# Iteration 492, Loss: 2.9379985332489014
# Iteration 492 - Learning Rate: 0.0009350918773347629
# Iteration 493, Loss: 6.3103532791137695
# Iteration 493 - Learning Rate: 0.0009348336473833823
# Iteration 494, Loss: 2.7126083374023438
# Iteration 494 - Learning Rate: 0.000934574940583592
# Iteration 495, Loss: 2.9912304878234863
# Iteration 495 - Learning Rate: 0.0009343157572190957
# Iteration 496, Loss: 3.24580717086792
# Iteration 496 - Learning Rate: 0.0009340560975741196
# Iteration 497, Loss: 2.81453800201416
# Iteration 497 - Learning Rate: 0.0009337959619334124
# Iteration 498, Loss: 2.925210475921631
# Iteration 498 - Learning Rate: 0.000933535350582245
# Iteration 499, Loss: 3.040037155151367
# Iteration 499 - Learning Rate: 0.0009332742638064094
# Iteration 500, Loss: 4.372828006744385
# Iteration 500 - Learning Rate: 0.0009330127018922194
# Iteration 501, Loss: 6.789926528930664
# Iteration 501 - Learning Rate: 0.0009327506651265095
# Iteration 502, Loss: 2.9045212268829346
# Iteration 502 - Learning Rate: 0.0009324881537966355
# Iteration 503, Loss: 2.9490723609924316
# Iteration 503 - Learning Rate: 0.0009322251681904728
# Iteration 504, Loss: 3.0158867835998535
# Iteration 504 - Learning Rate: 0.0009319617085964177
# Iteration 505, Loss: 2.7195003032684326
# Iteration 505 - Learning Rate: 0.0009316977753033859
# Iteration 506, Loss: 2.661813497543335
# Iteration 506 - Learning Rate: 0.0009314333686008126
# Iteration 507, Loss: 5.382386207580566
# Iteration 507 - Learning Rate: 0.0009311684887786521
# Iteration 508, Loss: 18.18097686767578
# Iteration 508 - Learning Rate: 0.0009309031361273777
# Iteration 509, Loss: 9.509729385375977
# Iteration 509 - Learning Rate: 0.000930637310937981
# Iteration 510, Loss: 2.898414373397827
# Iteration 510 - Learning Rate: 0.0009303710135019719
# Iteration 511, Loss: 6.678518295288086
# Iteration 511 - Learning Rate: 0.0009301042441113784
# Iteration 512, Loss: 2.951639413833618
# Iteration 512 - Learning Rate: 0.0009298370030587456
# Iteration 513, Loss: 2.892158031463623
# Iteration 513 - Learning Rate: 0.0009295692906371363
# Iteration 514, Loss: 5.04893159866333
# Iteration 514 - Learning Rate: 0.0009293011071401299
# Iteration 515, Loss: 2.981743574142456
# Iteration 515 - Learning Rate: 0.0009290324528618224
# Iteration 516, Loss: 2.908046007156372
# Iteration 516 - Learning Rate: 0.0009287633280968262
# Iteration 517, Loss: 2.9319753646850586
# Iteration 517 - Learning Rate: 0.0009284937331402696
# Iteration 518, Loss: 2.9582817554473877
# Iteration 518 - Learning Rate: 0.0009282236682877967
# Iteration 519, Loss: 3.0101287364959717
# Iteration 519 - Learning Rate: 0.0009279531338355665
# Iteration 520, Loss: 3.352983236312866
# Iteration 520 - Learning Rate: 0.0009276821300802533
# Iteration 521, Loss: 3.1469006538391113
# Iteration 521 - Learning Rate: 0.0009274106573190459
# Iteration 522, Loss: 3.082580804824829
# ...
# Iteration 2831 - Learning Rate: 7.809744501906564e-06
# Iteration 2832, Loss: 4.1942362785339355
# Iteration 2832 - Learning Rate: 7.717832735397263e-06
# Iteration 2833, Loss: 3.105823516845703
# Iteration 2833 - Learning Rate: 7.626460816643627e-06
# Iteration 2834, Loss: 2.8358840942382812
# Iteration 2834 - Learning Rate: 7.53562884584606e-06
# Iteration 2835, Loss: 3.336744785308838
# Iteration 2835 - Learning Rate: 7.445336922613051e-06
# Iteration 2836, Loss: 2.6510069370269775
# Iteration 2836 - Learning Rate: 7.355585145960726e-06
# Iteration 2837, Loss: 2.76883602142334
# Iteration 2837 - Learning Rate: 7.266373614312856e-06
# Iteration 2838, Loss: 2.9876885414123535
# Iteration 2838 - Learning Rate: 7.177702425500961e-06
# Iteration 2839, Loss: 3.1253843307495117
# Iteration 2839 - Learning Rate: 7.0895716767638145e-06
# Iteration 2840, Loss: 2.844722270965576
# Iteration 2840 - Learning Rate: 7.00198146474755e-06
# Iteration 2841, Loss: 3.1047325134277344
# Iteration 2841 - Learning Rate: 6.9149318855055575e-06
# Iteration 2842, Loss: 2.9089150428771973
# Iteration 2842 - Learning Rate: 6.828423034498474e-06
# Iteration 2843, Loss: 2.769172191619873
# Iteration 2843 - Learning Rate: 6.742455006593748e-06
# Iteration 2844, Loss: 2.7729716300964355
# Iteration 2844 - Learning Rate: 6.657027896065967e-06
# Iteration 2845, Loss: 3.4069762229919434
# Iteration 2845 - Learning Rate: 6.572141796596362e-06
# Iteration 2846, Loss: 3.139148235321045
# Iteration 2846 - Learning Rate: 6.487796801272969e-06
# Iteration 2847, Loss: 2.9990129470825195
# Iteration 2847 - Learning Rate: 6.4039930025904114e-06
# Iteration 2848, Loss: 2.477952480316162
# Iteration 2848 - Learning Rate: 6.320730492449787e-06
# Iteration 2849, Loss: 3.0091519355773926
# Iteration 2849 - Learning Rate: 6.238009362158724e-06
# Iteration 2850, Loss: 2.879239082336426
# Iteration 2850 - Learning Rate: 6.155829702431158e-06
# Iteration 2851, Loss: 2.91617488861084
# Iteration 2851 - Learning Rate: 6.074191603386946e-06
# Iteration 2852, Loss: 2.860553741455078
# Iteration 2852 - Learning Rate: 5.993095154552419e-06
# Iteration 2853, Loss: 2.5398736000061035
# Iteration 2853 - Learning Rate: 5.912540444859716e-06
# Iteration 2854, Loss: 3.1602935791015625
# Iteration 2854 - Learning Rate: 5.832527562647006e-06
# Iteration 2855, Loss: 3.0421595573425293
# Iteration 2855 - Learning Rate: 5.753056595658269e-06
# Iteration 2856, Loss: 2.6990034580230713
# Iteration 2856 - Learning Rate: 5.6741276310430144e-06
# Iteration 2857, Loss: 2.823439598083496
# Iteration 2857 - Learning Rate: 5.595740755356616e-06
# Iteration 2858, Loss: 2.4618427753448486
# Iteration 2858 - Learning Rate: 5.517896054559869e-06
# Iteration 2859, Loss: 4.1147780418396
# Iteration 2859 - Learning Rate: 5.440593614019097e-06
# Iteration 2860, Loss: 2.7377047538757324
# Iteration 2860 - Learning Rate: 5.363833518505824e-06
# Iteration 2861, Loss: 2.618976593017578
# Iteration 2861 - Learning Rate: 5.287615852196994e-06
# Iteration 2862, Loss: 2.866870641708374
# Iteration 2862 - Learning Rate: 5.211940698674524e-06
# Iteration 2863, Loss: 3.054513931274414
# Iteration 2863 - Learning Rate: 5.1368081409255326e-06
# Iteration 2864, Loss: 2.9525866508483887
# Iteration 2864 - Learning Rate: 5.062218261342113e-06
# Iteration 2865, Loss: 2.9222404956817627
# Iteration 2865 - Learning Rate: 4.9881711417211674e-06
# Iteration 2866, Loss: 2.7366318702697754
# Iteration 2866 - Learning Rate: 4.9146668632645745e-06
# Iteration 2867, Loss: 2.5813493728637695
# Iteration 2867 - Learning Rate: 4.841705506578579e-06
# Iteration 2868, Loss: 2.625424385070801
# Iteration 2868 - Learning Rate: 4.769287151674399e-06
# Iteration 2869, Loss: 3.127321243286133
# Iteration 2869 - Learning Rate: 4.697411877967565e-06
# Iteration 2870, Loss: 3.1388516426086426
# Iteration 2870 - Learning Rate: 4.626079764278194e-06
# Iteration 2871, Loss: 2.882138967514038
# Iteration 2871 - Learning Rate: 4.5552908888306024e-06
# Iteration 2872, Loss: 2.8605103492736816
# Iteration 2872 - Learning Rate: 4.485045329253638e-06
# Iteration 2873, Loss: 2.875026226043701
# Iteration 2873 - Learning Rate: 4.415343162580014e-06
# Iteration 2874, Loss: 2.830871820449829
# Iteration 2874 - Learning Rate: 4.346184465246698e-06
# Iteration 2875, Loss: 3.0662789344787598
# Iteration 2875 - Learning Rate: 4.277569313094802e-06
# Iteration 2876, Loss: 2.8518285751342773
# Iteration 2876 - Learning Rate: 4.209497781369136e-06
# Iteration 2877, Loss: 2.5673232078552246
# Iteration 2877 - Learning Rate: 4.141969944718598e-06
# Iteration 2878, Loss: 2.7525439262390137
# Iteration 2878 - Learning Rate: 4.074985877195618e-06
# Iteration 2879, Loss: 2.8541316986083984
# Iteration 2879 - Learning Rate: 4.008545652256495e-06
# Iteration 2880, Loss: 2.6775879859924316
# Iteration 2880 - Learning Rate: 3.942649342761056e-06
# Iteration 2881, Loss: 2.801811695098877
# Iteration 2881 - Learning Rate: 3.877297020972776e-06
# Iteration 2882, Loss: 2.845116138458252
# Iteration 2882 - Learning Rate: 3.8124887585583802e-06
# Iteration 2883, Loss: 2.6592955589294434
# Iteration 2883 - Learning Rate: 3.748224626588132e-06
# Iteration 2884, Loss: 2.6080169677734375
# Iteration 2884 - Learning Rate: 3.6845046955354907e-06
# Iteration 2885, Loss: 2.4897499084472656
# Iteration 2885 - Learning Rate: 3.6213290352772275e-06
# Iteration 2886, Loss: 3.1403603553771973
# Iteration 2886 - Learning Rate: 3.5586977150931463e-06
# Iteration 2887, Loss: 2.6831212043762207
# Iteration 2887 - Learning Rate: 3.4966108036661957e-06
# Iteration 2888, Loss: 2.9271950721740723
# Iteration 2888 - Learning Rate: 3.435068369082357e-06
# Iteration 2889, Loss: 2.9364235401153564
# Iteration 2889 - Learning Rate: 3.374070478830311e-06
# Iteration 2890, Loss: 2.995473861694336
# Iteration 2890 - Learning Rate: 3.3136171998017727e-06
# Iteration 2891, Loss: 3.0790929794311523
# Iteration 2891 - Learning Rate: 3.2537085982912675e-06
# Iteration 2892, Loss: 2.635669231414795
# Iteration 2892 - Learning Rate: 3.1943447399957984e-06
# Iteration 2893, Loss: 2.8727493286132812
# Iteration 2893 - Learning Rate: 3.13552569001518e-06
# Iteration 2894, Loss: 2.7486772537231445
# Iteration 2894 - Learning Rate: 3.077251512851705e-06
# Iteration 2895, Loss: 2.5604944229125977
# Iteration 2895 - Learning Rate: 3.019522272410198e-06
# Iteration 2896, Loss: 2.7940263748168945
# Iteration 2896 - Learning Rate: 2.962338031997687e-06
# Iteration 2897, Loss: 2.8616180419921875
# Iteration 2897 - Learning Rate: 2.9056988543238976e-06
# Iteration 2898, Loss: 2.7976512908935547
# Iteration 2898 - Learning Rate: 2.8496048015005344e-06
# Iteration 2899, Loss: 2.687689781188965
# Iteration 2899 - Learning Rate: 2.794055935041669e-06
# Iteration 2900, Loss: 3.06126070022583
# Iteration 2900 - Learning Rate: 2.739052315863351e-06
# Iteration 2901, Loss: 3.007995128631592
# Iteration 2901 - Learning Rate: 2.684594004283832e-06
# Iteration 2902, Loss: 4.1269402503967285
# Iteration 2902 - Learning Rate: 2.6306810600233395e-06
# Iteration 2903, Loss: 2.8223185539245605
# Iteration 2903 - Learning Rate: 2.5773135422040258e-06
# Iteration 2904, Loss: 3.2532148361206055
# Iteration 2904 - Learning Rate: 2.5244915093499095e-06
# Iteration 2905, Loss: 2.5182149410247803
# Iteration 2905 - Learning Rate: 2.4722150193868774e-06
# Iteration 2906, Loss: 2.8883399963378906
# Iteration 2906 - Learning Rate: 2.420484129642405e-06
# Iteration 2907, Loss: 3.0579981803894043
# Iteration 2907 - Learning Rate: 2.3692988968458362e-06
# Iteration 2908, Loss: 2.7320661544799805
# Iteration 2908 - Learning Rate: 2.3186593771280484e-06
# Iteration 2909, Loss: 2.9007718563079834
# Iteration 2909 - Learning Rate: 2.268565626021454e-06
# Iteration 2910, Loss: 2.765626907348633
# Iteration 2910 - Learning Rate: 2.2190176984599985e-06
# Iteration 2911, Loss: 2.7790024280548096
# Iteration 2911 - Learning Rate: 2.170015648779052e-06
# Iteration 2912, Loss: 3.110084295272827
# Iteration 2912 - Learning Rate: 2.1215595307154634e-06
# Iteration 2913, Loss: 2.831017017364502
# Iteration 2913 - Learning Rate: 2.0736493974071703e-06
# Iteration 2914, Loss: 2.9113636016845703
# Iteration 2914 - Learning Rate: 2.026285301393535e-06
# Iteration 2915, Loss: 3.020094394683838
# Iteration 2915 - Learning Rate: 1.9794672946152305e-06
# Iteration 2916, Loss: 2.8964009284973145
# Iteration 2916 - Learning Rate: 1.9331954284138e-06
# Iteration 2917, Loss: 2.8663458824157715
# Iteration 2917 - Learning Rate: 1.8874697535319867e-06
# Iteration 2918, Loss: 2.717780590057373
# Iteration 2918 - Learning Rate: 1.8422903201137902e-06
# Iteration 2919, Loss: 2.821096420288086
# Iteration 2919 - Learning Rate: 1.7976571777038013e-06
# Iteration 2920, Loss: 2.3918113708496094
# Iteration 2920 - Learning Rate: 1.753570375247812e-06
# Iteration 2921, Loss: 2.820040225982666
# Iteration 2921 - Learning Rate: 1.7100299610924823e-06
# Iteration 2922, Loss: 2.6055123805999756
# Iteration 2922 - Learning Rate: 1.6670359829850629e-06
# Iteration 2923, Loss: 3.0733628273010254
# Iteration 2923 - Learning Rate: 1.6245884880738389e-06
# Iteration 2924, Loss: 2.436758518218994
# Iteration 2924 - Learning Rate: 1.5826875229076307e-06
# Iteration 2925, Loss: 2.8174831867218018
# Iteration 2925 - Learning Rate: 1.5413331334360157e-06
# Iteration 2926, Loss: 2.7330939769744873
# Iteration 2926 - Learning Rate: 1.5005253650091065e-06
# Iteration 2927, Loss: 2.550555944442749
# Iteration 2927 - Learning Rate: 1.4602642623777729e-06
# Iteration 2928, Loss: 3.064514636993408
# Iteration 2928 - Learning Rate: 1.4205498696930307e-06
# Iteration 2929, Loss: 2.5938172340393066
# Iteration 2929 - Learning Rate: 1.3813822305067092e-06
# Iteration 2930, Loss: 2.9070427417755127
# Iteration 2930 - Learning Rate: 1.34276138777095e-06
# Iteration 2931, Loss: 2.8913822174072266
# Iteration 2931 - Learning Rate: 1.3046873838381525e-06
# Iteration 2932, Loss: 2.8258330821990967
# Iteration 2932 - Learning Rate: 1.2671602604612511e-06
# Iteration 2933, Loss: 2.847351551055908
# Iteration 2933 - Learning Rate: 1.2301800587932158e-06
# Iteration 2934, Loss: 2.75512433052063
# Iteration 2934 - Learning Rate: 1.193746819387385e-06
# Iteration 2935, Loss: 4.165772914886475
# Iteration 2935 - Learning Rate: 1.1578605821973548e-06
# Iteration 2936, Loss: 2.584763288497925
# Iteration 2936 - Learning Rate: 1.1225213865767008e-06
# Iteration 2937, Loss: 2.7632532119750977
# Iteration 2937 - Learning Rate: 1.0877292712792568e-06
# Iteration 2938, Loss: 2.635004758834839
# Iteration 2938 - Learning Rate: 1.0534842744588363e-06
# Iteration 2939, Loss: 2.683241844177246
# Iteration 2939 - Learning Rate: 1.0197864336691772e-06
# Iteration 2940, Loss: 2.273232936859131
# Iteration 2940 - Learning Rate: 9.866357858642191e-07
# Iteration 2941, Loss: 2.6997227668762207
# Iteration 2941 - Learning Rate: 9.540323673976046e-07
# Iteration 2942, Loss: 4.188213348388672
# Iteration 2942 - Learning Rate: 9.219762140231222e-07
# Iteration 2943, Loss: 2.5779409408569336
# Iteration 2943 - Learning Rate: 8.90467360894097e-07
# Iteration 2944, Loss: 2.9321603775024414
# Iteration 2944 - Learning Rate: 8.59505842564e-07
# Iteration 2945, Loss: 3.159832715988159
# Iteration 2945 - Learning Rate: 8.290916929858382e-07
# Iteration 2946, Loss: 2.9235692024230957
# Iteration 2946 - Learning Rate: 7.992249455124877e-07
# Iteration 2947, Loss: 2.74815034866333
# Iteration 2947 - Learning Rate: 7.699056328964715e-07
# Iteration 2948, Loss: 2.869711399078369
# Iteration 2948 - Learning Rate: 7.411337872900704e-07
# Iteration 2949, Loss: 2.720879554748535
# Iteration 2949 - Learning Rate: 7.129094402451565e-07
# Iteration 2950, Loss: 3.0490853786468506
# Iteration 2950 - Learning Rate: 6.852326227130824e-07
# Iteration 2951, Loss: 2.7736916542053223
# Iteration 2951 - Learning Rate: 6.581033650449033e-07
# Iteration 2952, Loss: 2.773183822631836
# Iteration 2952 - Learning Rate: 6.315216969912653e-07
# Iteration 2953, Loss: 2.66495418548584
# Iteration 2953 - Learning Rate: 6.05487647702129e-07
# Iteration 2954, Loss: 2.259511947631836
# Iteration 2954 - Learning Rate: 5.800012457270457e-07
# Iteration 2955, Loss: 2.9006309509277344
# Iteration 2955 - Learning Rate: 5.550625190150474e-07
# Iteration 2956, Loss: 3.1319594383239746
# Iteration 2956 - Learning Rate: 5.30671494914369e-07
# Iteration 2957, Loss: 2.669555425643921
# Iteration 2957 - Learning Rate: 5.068282001728922e-07
# Iteration 2958, Loss: 2.5870583057403564
# Iteration 2958 - Learning Rate: 4.83532660937646e-07
# Iteration 2959, Loss: 2.6832406520843506
# Iteration 2959 - Learning Rate: 4.607849027550286e-07
# Iteration 2960, Loss: 2.792658567428589
# Iteration 2960 - Learning Rate: 4.3858495057080773e-07
# Iteration 2961, Loss: 3.236724853515625
# Iteration 2961 - Learning Rate: 4.169328287299539e-07
# Iteration 2962, Loss: 2.588209390640259
# Iteration 2962 - Learning Rate: 3.9582856097658487e-07
# Iteration 2963, Loss: 2.7477307319641113
# Iteration 2963 - Learning Rate: 3.752721704541878e-07
# Iteration 2964, Loss: 2.8213882446289062
# Iteration 2964 - Learning Rate: 3.552636797053971e-07
# Iteration 2965, Loss: 2.8712849617004395
# Iteration 2965 - Learning Rate: 3.3580311067188346e-07
# Iteration 2966, Loss: 2.8116092681884766
# Iteration 2966 - Learning Rate: 3.168904846945759e-07
# Iteration 2967, Loss: 3.180647373199463
# Iteration 2967 - Learning Rate: 2.9852582251355073e-07
# Iteration 2968, Loss: 2.9648170471191406
# Iteration 2968 - Learning Rate: 2.8070914426786506e-07
# Iteration 2969, Loss: 2.454113006591797
# Iteration 2969 - Learning Rate: 2.634404694956678e-07
# Iteration 2970, Loss: 3.1427974700927734
# Iteration 2970 - Learning Rate: 2.4671981713419956e-07
# Iteration 2971, Loss: 2.8765745162963867
# Iteration 2971 - Learning Rate: 2.305472055197373e-07
# Iteration 2972, Loss: 2.986079692840576
# Iteration 2972 - Learning Rate: 2.1492265238748325e-07
# Iteration 2973, Loss: 2.7759439945220947
# Iteration 2973 - Learning Rate: 1.9984617487173137e-07
# Iteration 2974, Loss: 2.8616702556610107
# Iteration 2974 - Learning Rate: 1.8531778950564536e-07
# Iteration 2975, Loss: 2.5600523948669434
# Iteration 2975 - Learning Rate: 1.7133751222136976e-07
# Iteration 2976, Loss: 2.8659520149230957
# Iteration 2976 - Learning Rate: 1.5790535835002976e-07
# Iteration 2977, Loss: 2.9402222633361816
# Iteration 2977 - Learning Rate: 1.450213426215649e-07
# Iteration 2978, Loss: 4.110027313232422
# Iteration 2978 - Learning Rate: 1.3268547916495095e-07
# Iteration 2979, Loss: 2.847834825515747
# Iteration 2979 - Learning Rate: 1.2089778150797792e-07
# Iteration 2980, Loss: 2.7150564193725586
# Iteration 2980 - Learning Rate: 1.0965826257724999e-07
# Iteration 2981, Loss: 2.8511147499084473
# Iteration 2981 - Learning Rate: 9.896693469829668e-08
# Iteration 2982, Loss: 4.356709003448486
# Iteration 2982 - Learning Rate: 8.882380959551722e-08
# Iteration 2983, Loss: 2.9642257690429688
# Iteration 2983 - Learning Rate: 7.922889839201404e-08
# Iteration 2984, Loss: 3.1929969787597656
# Iteration 2984 - Learning Rate: 7.018221160981483e-08
# Iteration 2985, Loss: 2.5857677459716797
# Iteration 2985 - Learning Rate: 6.168375916970601e-08
# Iteration 2986, Loss: 4.105198860168457
# Iteration 2986 - Learning Rate: 5.373355039128824e-08
# Iteration 2987, Loss: 2.891842842102051
# Iteration 2987 - Learning Rate: 4.6331593993031894e-08
# Iteration 2988, Loss: 2.981187105178833
# Iteration 2988 - Learning Rate: 3.947789809194404e-08
# Iteration 2989, Loss: 3.0701770782470703
# Iteration 2989 - Learning Rate: 3.3172470204012516e-08
# Iteration 2990, Loss: 2.7448649406433105
# Iteration 2990 - Learning Rate: 2.7415317243928362e-08
# Iteration 2991, Loss: 3.043259620666504
# Iteration 2991 - Learning Rate: 2.2206445525085832e-08
# Iteration 2992, Loss: 2.8907952308654785
# Iteration 2992 - Learning Rate: 1.7545860759693404e-08
# Iteration 2993, Loss: 2.85898494720459
# Iteration 2993 - Learning Rate: 1.3433568058607261e-08
# Iteration 2994, Loss: 2.979977607727051
# Iteration 2994 - Learning Rate: 9.86957193144231e-09
# Iteration 2995, Loss: 2.95037841796875
# Iteration 2995 - Learning Rate: 6.8538762866276865e-09
# Iteration 2996, Loss: 2.4823999404907227
# Iteration 2996 - Learning Rate: 4.3864844311847125e-09
# Iteration 2997, Loss: 2.6035585403442383
# Iteration 2997 - Learning Rate: 2.467399070893433e-09
# Iteration 2998, Loss: 2.9047770500183105
# Iteration 2998 - Learning Rate: 1.096622310348125e-09
# Iteration 2999, Loss: 2.730020523071289
# Iteration 2999 - Learning Rate: 2.741556527352522e-10

# %%
print(torch.exp(model.data_transform.log_sigma))
print(model.data_transform.gamma)
# Out:
# tensor([0.5303, 0.4191], device='cuda:0', grad_fn=<ExpBackward0>)
# Parameter containing:
# tensor([0.0624, 0.0494], device='cuda:0', requires_grad=True)

# %%
samples.shape
# Out:
# (498, 2)

# %%
samples_obs, samples_std, samples_T= model.sample(10000)
plt.figure(figsize=(8,8))
plt.subplot(2, 2, 1)
plt.scatter(samples_obs[:,0].cpu().data.numpy(), samples_obs[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples on observational scale')
plt.subplot(2, 2, 2)
plt.scatter(samples_std[:,0].cpu().data.numpy(), samples_std[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples on standardized scale')
plt.subplot(2, 2, 3)
plt.scatter(samples_T[:,0].cpu().data.numpy(), samples_T[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples from Normalizing Flow')
plt.show()

# %%
plt.subplot(1, 2, 1)
sns.distplot(samples[:,0], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
sns.distplot(samples_obs[:,0].cpu().data.numpy(), hist=False, kde=True,
             bins=None, color='firebrick',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='flow')
plt.title(r'$p(x_1)$')
plt.subplot(1, 2, 2)
sns.distplot(samples[:,1], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
sns.distplot(samples_obs[:,1].cpu().data.numpy(), hist=False, kde=True,
             bins=None, color='firebrick',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='flow')
plt.title(r'$p(x_2)$')
plt.show()
# Out:
# /tmp/ipykernel_4165448/2014099692.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,0], hist=False, kde=True,
# /tmp/ipykernel_4165448/2014099692.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples_obs[:,0].cpu().data.numpy(), hist=False, kde=True,
# /tmp/ipykernel_4165448/2014099692.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,1], hist=False, kde=True,
# /tmp/ipykernel_4165448/2014099692.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples_obs[:,1].cpu().data.numpy(), hist=False, kde=True,

# %%
sns.distplot(samples[:,1], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
# Out:
# /tmp/ipykernel_4165448/2863656582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,1], hist=False, kde=True,
# <Axes: ylabel='Density'>

# %%
def empirical_upper_tail_dependence(X1, X2, q):
    """
    Calculate empirical upper tail dependence coefficient.

    Parameters:
    X1, X2 : numpy arrays
        Samples from two random variables.
    q : float
        Quantile threshold (close to 1, e.g., 0.95 or 0.99).

    Returns:
    lambda_u : float
        Empirical upper tail dependence coefficient.
    """
    # Compute the quantiles
    F1_q = np.quantile(X1, q)
    F2_q = np.quantile(X2, q)
    
    # Count joint exceedances
    joint_exceedance = np.sum((X1 > F1_q) & (X2 > F2_q))
    exceedance_X1 = np.sum(X1 > F1_q)
    
    # Calculate lambda_u
    if exceedance_X1 == 0:  # Avoid division by zero
        return 0.0
    lambda_u = joint_exceedance / exceedance_X1
    return lambda_u


def plot_tail_dependence(X1, X2, quantiles):
    """
    Plot upper tail dependence vs quantiles.

    Parameters:
    X1, X2 : numpy arrays
        Samples from two random variables.
    quantiles : list or array
        List of quantiles to evaluate (e.g., np.linspace(0.9, 0.99, 50)).
    """
    # Compute lambda_u for each quantile
    lambda_values = [empirical_upper_tail_dependence(X1, X2, q) for q in quantiles]
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(quantiles, lambda_values, marker='o', linestyle='-')
    plt.xlabel('Quantile (q)')
    plt.ylabel(r'$\lambda_u$ (Upper Tail Dependence)')
    plt.title('Upper Tail Dependence vs Quantiles')
    plt.grid(True)
    plt.show()

# Example usage
np.random.seed(42)
X1 = samples[:,0]
X2 = samples[:,1]

# Define quantiles (e.g., from 0.90 to 0.99)
quantiles = np.linspace(0.50, 0.990, 100)

# Plot the tail dependence
plot_tail_dependence(X1, X2, quantiles)
# Compute lambda_u at 0.95 quantile
q = 0.99
lambda_u = empirical_upper_tail_dependence(X1, X2, q)
print(f"Empirical upper tail dependence: {lambda_u}")
# Out:
# Empirical upper tail dependence: 0.0

# %%
X1 = samples_obs[:,0].cpu().data.numpy()
X2 = samples_obs[:,1].cpu().data.numpy()

# Define quantiles (e.g., from 0.90 to 0.99)
quantiles = np.linspace(0.50, 0.990, 100)

# Plot the tail dependence
plot_tail_dependence(X1, X2, quantiles)
# Compute lambda_u at 0.95 quantile
q = 0.99
lambda_u = empirical_upper_tail_dependence(X1, X2, q)
print(f"Empirical upper tail dependence: {lambda_u}")
# Out:
# Empirical upper tail dependence: 0.05

# %%
X1 = samples_obs[:,0].cpu().data.numpy()
X2 = samples_obs[:,1].cpu().data.numpy()
chi = []
for i in range(100):
    samples_obs, samples_std, samples_T= model.sample(10000)
    X1 = samples_obs[:,0].cpu().data.numpy()
    X2 = samples_obs[:,1].cpu().data.numpy()
    chi.append(empirical_upper_tail_dependence(X1,X2,0.99))

# %%
sns.distplot(chi, hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
# Out:
# /tmp/ipykernel_4165448/1578080669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(chi, hist=False, kde=True,
# <Axes: ylabel='Density'>
