# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import normflows as nf
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from tqdm import tqdm
print(f"Using device: {device}")
# Out:
# /home/pgrad2/2448355h/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Using device: cuda

# %%
def sim_revexp_u_mgpd(n, d, a, beta, sig, gamma, MGPD=True, std=False):
    lam = np.exp(beta)
    Y = np.zeros((n, d))
    C = 1 / np.min(lam)
    k = 0

    while k < n:
        U = np.random.uniform(0, 1, d)
        W = (U ** a) / lam
        R = np.random.uniform(0, C)
        
        Ind = R < np.max(W)
        
        if Ind:
            Y[k, :] = W / R
            k += 1

    if std and not MGPD:
        return np.log(Y)

    X = []
    for j in range(d):
        if gamma[j] != 0:
            X.append(sig[j] * (Y[:, j] ** gamma[j] - 1) / gamma[j])
        else:
            X.append(sig[j] * np.log(Y[:, j]))
    X = np.column_stack(X)

    if MGPD and not std:
        return X
    if std and MGPD:
        return {'X': X, 'Z': np.log(Y)}

# %%
n_samples = 10000
d = 2
a = np.array([3,0.5])
beta = np.array([0, 0])
sig = np.array([2,3])
gamma = np.array([-0.1, 0.2])

samples = sim_revexp_u_mgpd(n_samples, d, a, beta, sig, gamma)

# Visualize the samples
plt.scatter(samples[:, 0], samples[:, 1], alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Scatter plot of 1000 samples from the MGPD')
plt.grid(True)
plt.show()

# %%
# mean = [0, 0]
# cov = [[3, 0.5], [0.5, 2]] 
# x, y = np.random.multivariate_normal(mean, cov, 50000).T
# samples = np.stack([x,y],axis=1)
# u = np.quantile(samples, 0.97,axis=0)
# print(u)
# samples = samples[(samples[:,0] > u[0] ) | (samples[:,1] > u[1] ),:]
# u = u.reshape(1,-1)
# samples = samples - u
# plt.scatter(samples[:, 0], samples[:, 1], alpha=1)
# plt.axis('equal')
# plt.show()
# Out:
# [3.24471367 2.66359579]

# %%
class DataTransform(nn.Module):
    """
    Elementwise transform:
      If gamma_j = 0:
        forward_transform(y_j): x_j = sigma_j * y_j
        inverse_transform(x_j): y_j = x_j / sigma_j
      Otherwise (gamma_j != 0):
        forward_transform(y_j): x_j = sigma_j * [exp(gamma_j * y_j) - 1] / gamma_j
        inverse_transform(x_j): y_j = (1 / gamma_j)* log(1 + gamma_j * x_j / sigma_j)
    """

    def __init__(self, dim, device):
        super().__init__()
        self.dim = dim
        # Store log_sigma so sigma = exp(log_sigma) > 0
        self.log_sigma = nn.Parameter(torch.zeros(dim, device=device))
        # gamma can be any real value
        self.gamma = nn.Parameter(torch.zeros(dim, device=device)+1e-6)

    def forward_transform(self, y):
        """
        y -> x
        """
        sigma = torch.exp(self.log_sigma)  # shape (dim,)
        sigma = torch.clamp(sigma, min = 1e-6, max = 1e6)
        gamma = self.gamma                # shape (dim,)
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))
        
        # We'll do it elementwise, but in a vectorized way.
        # y and x are shape (batch_size, dim).
    
        x_out = torch.zeros_like(y)

        # For gamma_j = 0 => x_j = sigma_j * y_j
        # For gamma_j != 0 => x_j = sigma_j*(exp(gamma_j*y_j) - 1)/gamma_j
        # We can use torch.where(...) to handle each dimension separately.

        # Expand so shapes match for broadcasting
        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

        # Exponential case: x_j = sigma_j*(exp(gamma_j*y_j) - 1)/gamma_j
        x_out = sigma * (torch.exp(torch.clamp(gamma * y, max=10)) - 1.0) / gamma

        return x_out

    def inverse_transform(self, x):
        """
        x -> y
        """
        sigma = torch.exp(self.log_sigma)  # shape (dim,)
        sigma = torch.clamp(sigma, min = 1e-6, max = 1e6)
        gamma = self.gamma                # shape (dim,)
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))

        y_out = torch.zeros_like(x)

        # For gamma_j = 0 => y_j = x_j / sigma_j
        # For gamma_j != 0 => y_j = (1/gamma_j)* log(1 + gamma_j*x_j / sigma_j)
        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

#         gamma_is_zero = (gamma.abs() < 1e-6)

#         # Linear case: y_j = x_j / sigma_j
#         y_linear = x / sigma

        # Exponential (inverse) case: y_j = (1/gamma_j)* log(1 + gamma_j*x_j / sigma_j)
        inside = 1.0 + (gamma * x) / sigma
        inside = torch.clamp(inside, min=1e-12) 
        y_out = (1.0 / gamma) * torch.log(inside)

#         y_out = torch.where(gamma_is_zero, y_linear, y_exp)
        return y_out

    def forward(self, z, reverse=False):
        """
        For normflows compatibility:
          - If reverse=False: we do y->x
          - If reverse=True: we do x->y
        """
        if not reverse:
            return self.forward_transform(z)
        else:
            return self.inverse_transform(z)

# %%
class T_mGPD_NF(nn.Module):
    """
    Interpreting:
       x = observed data (size=dim)
       y = standardized data
    We have:

      DataTransform.forward_transform(y)   = x
      DataTransform.inverse_transform(x)   = y

    So in 'forward(x)', to get minus log-likelihood of data x:
       1) We do y = inverse_transform(x)
       2) log_p_flow(y) = flow_model.log_prob(y)
       3) The log-det Jacobian of x->y is the sum of log(d y_i / d x_i).
          We'll compute that from the known formula for inverse_transform.
    """
    def __init__(self, dim, flow, device, s_min , s_max, num_integration_points, penalty_lambda):
        super().__init__()
        self.dim = dim
        # Learnable data transformation
        self.data_transform = DataTransform(dim, device)
        # RealNVP flow model
        self.flow_model = flow
        self.device = device
        self.s_values = torch.linspace(s_min, s_max, num_integration_points, device=device)
        self.s_values = self.s_values.reshape(-1, 1, 1)
        self.s_min = s_min
        self.s_max = s_max
        self.num_integration_points = num_integration_points
        self.penalty_lambda = penalty_lambda
        
    def log_integral_f_T(self, data):
            # Expand batch_x to match s_values
        batch_size = data.shape[0]
        dim = data.shape[1]
        
        x_expanded = data.unsqueeze(0)  # Shape (1, effective_batch_size, dim)
        x_expanded = x_expanded.expand(self.num_integration_points, -1, -1)  # Shape (num_points, batch_size, dim)

        # Expand s_values to match batch size and dimension
        s_expanded = self.s_values.expand(-1, batch_size, 1)  # Shape (num_points, batch_size, 1)

        # Compute x + s for all s_values
        x_plus_s = x_expanded + s_expanded  # Broadcasting over the last dimension
        x_plus_s = x_plus_s.reshape(-1, dim)  # Flatten to (num_points * batch_size, dim)

        log_f_T = self.flow_model.log_prob(x_plus_s)  # Shape (num_points * batch_size,)
        log_integrand = log_f_T.reshape(self.num_integration_points, batch_size)
        
        # 1. log-sum-exp over 'num_points' dimension
        max_vals, _ = torch.max(log_integrand, dim=0, keepdim=True)  # shape (1, batch_size)
        stable_exp = torch.exp(log_integrand - max_vals)             # shape (num_points, batch_size)
        
        delta_s = (self.s_max - self.s_min) / (self.num_integration_points - 1)
        sum_exp = torch.trapz(stable_exp, dx=delta_s, dim=0)         # shape (batch_size,)
        # 2. Now put the max_vals back in:
        log_integral = max_vals.squeeze(0) + torch.log(sum_exp + 1e-40)  # shape (batch_size,)
        
        return log_integral
    
    def log_prob_T_mGPD_std(self, data):
        log_integral = self.log_integral_f_T(data)
        max_T = torch.max(data, dim=1)[0]
        
        log_prob = log_integral - max_T
        return log_prob
    
    
        

    def forward(self, x_data):
        """
        Return minus log p_data(x_data).
        We do:
          y = T_inv(x_data)  [since T_inv is x->y]
          log p_data(x_data) = log p_flow(y) + log|det(d y / d x)|
        """
        # 1) x->y
        y = self.data_transform.inverse_transform(x_data)

        # 2) log prob under flow
        log_prob_y = self.log_prob_T_mGPD_std(y)

        # 3) log | det dy/dx |
        #    From y_i = 1/gamma_i * log(1 + gamma_i*x_i / sigma_i),
        #    dy_i/dx_i = 1 / [sigma_i + gamma_i * x_i].
        sigma = torch.exp(self.data_transform.log_sigma)  # shape (dim,)
        gamma = self.data_transform.gamma                 # shape (dim,)

        sigma = torch.clamp(sigma, min = 0.01, max = 100)
        
        gamma = torch.clamp(gamma, min = -0.5, max = 0.5)
        gamma = gamma.sign() * torch.max(gamma.abs(), torch.tensor(1e-6, device=gamma.device))

        sigma = sigma.unsqueeze(0)  # (1, dim)
        gamma = gamma.unsqueeze(0)  # (1, dim)

        # Build inside = sigma + gamma*x
        inside = sigma + gamma * x_data

        # log_abs_detJ per sample = - sum_j log(inside_j)
        log_abs_detJ = -torch.sum(torch.log(inside.abs() + 1e-12), dim=1)
        
        # => log p(x_data) = log p(y) + log|det dy/dx|
        log_prob_x = log_prob_y + log_abs_detJ
        
        ######## Soft penalty: penalize negative (sigma_j + gamma_j*x_j)
        negative_part = torch.relu(-inside)  # = max(0, -(inside)) => positive if inside<0
        # penalty = sum_j [ negative_part^2 ] over j, average over batch
        penalty_per_sample = (negative_part ** 2).sum(dim=1)
        penalty = self.penalty_lambda * penalty_per_sample.mean()
        
        return -log_prob_x.mean() +  penalty 

    def sample(self, n_samples=1):
        """
        Sample from the learned distribution in x-space by:
          1) Sample y ~ flow
          2) Convert y->x using forward_transform
        """
        self.flow_model.eval()
        samples_T,_ = self.flow_model.sample(n_samples)
        self.flow_model.train()
        
        samples_T_max = torch.max(samples_T,axis=1,keepdim=True)[0]
        samples_T_1 = samples_T - samples_T_max
        
        samples_E  = torch.empty(n_samples, device=self.device)
        samples_E = samples_E.exponential_(1.0).unsqueeze(1)
        
        samples_y = samples_E + samples_T_1

        samples_x = self.data_transform.forward_transform(samples_y)  # y->x
        return samples_x, samples_y, samples_T

# %%
data = torch.tensor(samples, dtype=torch.float, device = device)

# %%
memory = torch.cuda.memory_allocated(device) /10**9
print('{:.2f}G GPU memory allocated'.format(memory))
# Out:
# 0.00G GPU memory allocated

# %%
dim = 2
base = nf.distributions.base.DiagGaussian(2)

num_layers = 16
flows = []
for i in range(num_layers):
    # Neural network with two hidden layers having 64 units each
    # Last layer is initialized by zeros making training more stable
    param_map = nf.nets.MLP([1, 20, 20, 2], init_zeros=True)
    # Add flow layer
    flows.append(nf.flows.AffineCouplingBlock(param_map))
    # Swap dimensions
    flows.append(nf.flows.Permute(2, mode='swap'))
    
f_T_model = nf.NormalizingFlow(base, flows)
f_T_model = f_T_model.to(device)


batch_size = 128
num_iterations = 2000
loss_history = []
show_iter = 200

model = T_mGPD_NF(dim=2, flow =f_T_model, device=device, s_min=-10,
                  s_max = 10, num_integration_points=1000, penalty_lambda=10000)

# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4,weight_decay=1e-5)
optimizer = torch.optim.Adam([
    {'params': model.flow_model.parameters(), 'lr': 1e-4},  # Flow layers
    {'params': model.data_transform.log_sigma, 'lr': 1e-1},  # Faster for log_sigma
    {'params': model.data_transform.gamma, 'lr': 1e-2}       # Faster for gamma
])
# for name, param in model.named_parameters():
#     print(name, param)

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_iterations)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
#     optimizer, mode='min', factor=0.5, patience=10, verbose=True
# )
for it in range(num_iterations):
    # Sample a batch of data from h_U
    idx = np.random.choice(data.shape[0], batch_size, replace=False)
    x_data = data[idx]  # Shape (batch_size, dim)
    
    batch_loss = model(x_data)
    
    # Backpropagation
    optimizer.zero_grad()
    batch_loss.backward()
    
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)

    
    optimizer.step()
    
    # Record loss
    loss_history.append(batch_loss.item())
    
    if torch.isnan(batch_loss) or torch.isinf(batch_loss):
        print("NaN or Inf detected!")
        break
    
    if it % 1 == 0:
        print(f"Iteration {it}, Loss: {batch_loss.item()}")
        current_lr = optimizer.param_groups[0]['lr']
    
        print(f"Iteration {it} - Learning Rate: {current_lr}")
        # Debugging: Print shapes
    if it % show_iter == 0:
        
        samples_obs, samples_std, samples_T= model.sample(n_samples)
        
        samples_obs, samples_std, samples_T= model.sample(n_samples)
        plt.figure(figsize=(8,8))
        plt.subplot(2, 2, 1)
        plt.scatter(samples_obs[:,0].cpu().data.numpy(), samples_obs[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples on observational scale')
        plt.subplot(2, 2, 2)
        plt.scatter(samples_std[:,0].cpu().data.numpy(), samples_std[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples on standardized scale')
        plt.subplot(2, 2, 3)
        plt.scatter(samples_T[:,0].cpu().data.numpy(), samples_T[:,1].cpu().data.numpy(), alpha=0.5, color='red')
        plt.title('Samples from Normalizing Flow')
        plt.show()
    

    scheduler.step()
    
# Plot the training loss
plt.figure()
plt.plot(loss_history)
plt.title('Training Loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.show()
# Out:
# Iteration 0, Loss: 171.15599060058594
# Iteration 0 - Learning Rate: 0.0001
# Iteration 1, Loss: 23.571056365966797
# Iteration 1 - Learning Rate: 9.999993831498517e-05
# Iteration 2, Loss: 31.271408081054688
# Iteration 2 - Learning Rate: 9.999975326009292e-05
# Iteration 3, Loss: 20.495309829711914
# Iteration 3 - Learning Rate: 9.999944483577981e-05
# Iteration 4, Loss: 13.857280731201172
# Iteration 4 - Learning Rate: 9.999901304280685e-05
# Iteration 5, Loss: 11.582415580749512
# Iteration 5 - Learning Rate: 9.999845788223949e-05
# Iteration 6, Loss: 11.418384552001953
# Iteration 6 - Learning Rate: 9.99977793554475e-05
# Iteration 7, Loss: 9.372501373291016
# Iteration 7 - Learning Rate: 9.999697746410508e-05
# Iteration 8, Loss: 7.674544811248779
# Iteration 8 - Learning Rate: 9.999605221019082e-05
# Iteration 9, Loss: 8.339043617248535
# Iteration 9 - Learning Rate: 9.999500359598769e-05
# Iteration 10, Loss: 7.303754806518555
# Iteration 10 - Learning Rate: 9.999383162408305e-05
# Iteration 11, Loss: 6.8988189697265625
# Iteration 11 - Learning Rate: 9.999253629736862e-05
# Iteration 12, Loss: 7.77699613571167
# Iteration 12 - Learning Rate: 9.999111761904047e-05
# Iteration 13, Loss: 6.795952320098877
# Iteration 13 - Learning Rate: 9.998957559259908e-05
# Iteration 14, Loss: 6.382902145385742
# Iteration 14 - Learning Rate: 9.998791022184923e-05
# Iteration 15, Loss: 6.574681282043457
# Iteration 15 - Learning Rate: 9.998612151090006e-05
# Iteration 16, Loss: 6.0427565574646
# Iteration 16 - Learning Rate: 9.998420946416502e-05
# Iteration 17, Loss: 6.063871383666992
# Iteration 17 - Learning Rate: 9.998217408636191e-05
# Iteration 18, Loss: 5.960296154022217
# Iteration 18 - Learning Rate: 9.998001538251282e-05
# Iteration 19, Loss: 6.218530178070068
# Iteration 19 - Learning Rate: 9.997773335794416e-05
# Iteration 20, Loss: 6.125502109527588
# Iteration 20 - Learning Rate: 9.997532801828658e-05
# Iteration 21, Loss: 6.027458190917969
# Iteration 21 - Learning Rate: 9.9972799369475e-05
# Iteration 22, Loss: 5.935076713562012
# Iteration 22 - Learning Rate: 9.997014741774864e-05
# Iteration 23, Loss: 6.12086296081543
# Iteration 23 - Learning Rate: 9.996737216965092e-05
# Iteration 24, Loss: 6.057653427124023
# Iteration 24 - Learning Rate: 9.996447363202946e-05
# Iteration 25, Loss: 5.7575507164001465
# Iteration 25 - Learning Rate: 9.996145181203615e-05
# Iteration 26, Loss: 5.94387149810791
# Iteration 26 - Learning Rate: 9.9958306717127e-05
# Iteration 27, Loss: 6.143957138061523
# Iteration 27 - Learning Rate: 9.995503835506225e-05
# Iteration 28, Loss: 5.658624649047852
# Iteration 28 - Learning Rate: 9.995164673390623e-05
# Iteration 29, Loss: 6.257565498352051
# Iteration 29 - Learning Rate: 9.994813186202745e-05
# Iteration 30, Loss: 5.773736000061035
# Iteration 30 - Learning Rate: 9.994449374809851e-05
# Iteration 31, Loss: 5.884768486022949
# Iteration 31 - Learning Rate: 9.994073240109606e-05
# Iteration 32, Loss: 6.2358551025390625
# Iteration 32 - Learning Rate: 9.993684783030088e-05
# Iteration 33, Loss: 6.0874104499816895
# Iteration 33 - Learning Rate: 9.993284004529775e-05
# Iteration 34, Loss: 5.926529407501221
# Iteration 34 - Learning Rate: 9.992870905597548e-05
# Iteration 35, Loss: 6.1434831619262695
# Iteration 35 - Learning Rate: 9.99244548725269e-05
# Iteration 36, Loss: 5.563874244689941
# Iteration 36 - Learning Rate: 9.992007750544875e-05
# Iteration 37, Loss: 5.831982612609863
# Iteration 37 - Learning Rate: 9.991557696554176e-05
# Iteration 38, Loss: 5.943763732910156
# Iteration 38 - Learning Rate: 9.99109532639106e-05
# Iteration 39, Loss: 6.201026916503906
# Iteration 39 - Learning Rate: 9.990620641196372e-05
# Iteration 40, Loss: 5.972811698913574
# Iteration 40 - Learning Rate: 9.990133642141357e-05
# Iteration 41, Loss: 5.903684616088867
# Iteration 41 - Learning Rate: 9.989634330427634e-05
# Iteration 42, Loss: 6.0243353843688965
# Iteration 42 - Learning Rate: 9.989122707287208e-05
# Iteration 43, Loss: 5.624188423156738
# Iteration 43 - Learning Rate: 9.988598773982454e-05
# Iteration 44, Loss: 5.513507843017578
# Iteration 44 - Learning Rate: 9.988062531806126e-05
# Iteration 45, Loss: 63.473548889160156
# Iteration 45 - Learning Rate: 9.987513982081351e-05
# Iteration 46, Loss: 5.916330337524414
# Iteration 46 - Learning Rate: 9.986953126161619e-05
# Iteration 47, Loss: 5.825939178466797
# Iteration 47 - Learning Rate: 9.986379965430786e-05
# Iteration 48, Loss: 5.783740997314453
# Iteration 48 - Learning Rate: 9.985794501303071e-05
# Iteration 49, Loss: 5.544561386108398
# Iteration 49 - Learning Rate: 9.985196735223047e-05
# Iteration 50, Loss: 5.652647018432617
# Iteration 50 - Learning Rate: 9.984586668665642e-05
# Iteration 51, Loss: 5.878539085388184
# Iteration 51 - Learning Rate: 9.983964303136134e-05
# Iteration 52, Loss: 5.795505523681641
# Iteration 52 - Learning Rate: 9.98332964017015e-05
# Iteration 53, Loss: 5.645155906677246
# Iteration 53 - Learning Rate: 9.982682681333658e-05
# Iteration 54, Loss: 5.788286209106445
# Iteration 54 - Learning Rate: 9.982023428222962e-05
# Iteration 55, Loss: 5.960788726806641
# Iteration 55 - Learning Rate: 9.981351882464706e-05
# Iteration 56, Loss: 5.600680351257324
# Iteration 56 - Learning Rate: 9.980668045715864e-05
# Iteration 57, Loss: 5.823727607727051
# Iteration 57 - Learning Rate: 9.97997191966373e-05
# Iteration 58, Loss: 5.673449516296387
# Iteration 58 - Learning Rate: 9.97926350602593e-05
# Iteration 59, Loss: 74.12947082519531
# Iteration 59 - Learning Rate: 9.978542806550403e-05
# Iteration 60, Loss: 5.7111616134643555
# Iteration 60 - Learning Rate: 9.977809823015401e-05
# Iteration 61, Loss: 5.6925249099731445
# Iteration 61 - Learning Rate: 9.977064557229492e-05
# Iteration 62, Loss: 5.453492641448975
# Iteration 62 - Learning Rate: 9.976307011031543e-05
# Iteration 63, Loss: 5.505992412567139
# Iteration 63 - Learning Rate: 9.975537186290724e-05
# Iteration 64, Loss: 26.116680145263672
# Iteration 64 - Learning Rate: 9.974755084906502e-05
# Iteration 65, Loss: 5.591524600982666
# Iteration 65 - Learning Rate: 9.973960708808632e-05
# Iteration 66, Loss: 5.788042068481445
# Iteration 66 - Learning Rate: 9.97315405995716e-05
# Iteration 67, Loss: 5.691627502441406
# Iteration 67 - Learning Rate: 9.972335140342413e-05
# Iteration 68, Loss: 53.16005325317383
# Iteration 68 - Learning Rate: 9.971503951984993e-05
# Iteration 69, Loss: 5.6470746994018555
# Iteration 69 - Learning Rate: 9.970660496935773e-05
# Iteration 70, Loss: 5.5951032638549805
# Iteration 70 - Learning Rate: 9.969804777275897e-05
# Iteration 71, Loss: 25.7899227142334
# Iteration 71 - Learning Rate: 9.968936795116765e-05
# Iteration 72, Loss: 5.724271297454834
# Iteration 72 - Learning Rate: 9.968056552600039e-05
# Iteration 73, Loss: 5.555192947387695
# Iteration 73 - Learning Rate: 9.967164051897629e-05
# Iteration 74, Loss: 5.701720714569092
# Iteration 74 - Learning Rate: 9.966259295211694e-05
# Iteration 75, Loss: 5.576530456542969
# Iteration 75 - Learning Rate: 9.96534228477463e-05
# Iteration 76, Loss: 5.976047515869141
# Iteration 76 - Learning Rate: 9.964413022849065e-05
# Iteration 77, Loss: 5.692127227783203
# Iteration 77 - Learning Rate: 9.963471511727865e-05
# Iteration 78, Loss: 5.397784233093262
# Iteration 78 - Learning Rate: 9.962517753734116e-05
# Iteration 79, Loss: 5.504568099975586
# Iteration 79 - Learning Rate: 9.961551751221117e-05
# Iteration 80, Loss: 5.693958282470703
# Iteration 80 - Learning Rate: 9.960573506572386e-05
# Iteration 81, Loss: 5.43619966506958
# Iteration 81 - Learning Rate: 9.959583022201643e-05
# Iteration 82, Loss: 48.44611740112305
# Iteration 82 - Learning Rate: 9.958580300552811e-05
# Iteration 83, Loss: 17.29076385498047
# Iteration 83 - Learning Rate: 9.957565344100003e-05
# Iteration 84, Loss: 5.348320007324219
# Iteration 84 - Learning Rate: 9.956538155347528e-05
# Iteration 85, Loss: 28.920434951782227
# Iteration 85 - Learning Rate: 9.95549873682987e-05
# Iteration 86, Loss: 5.727145195007324
# Iteration 86 - Learning Rate: 9.954447091111689e-05
# Iteration 87, Loss: 5.435866832733154
# Iteration 87 - Learning Rate: 9.953383220787817e-05
# Iteration 88, Loss: 5.651083946228027
# Iteration 88 - Learning Rate: 9.952307128483249e-05
# Iteration 89, Loss: 5.835944652557373
# Iteration 89 - Learning Rate: 9.951218816853138e-05
# Iteration 90, Loss: 5.744025707244873
# Iteration 90 - Learning Rate: 9.950118288582781e-05
# Iteration 91, Loss: 5.590419769287109
# Iteration 91 - Learning Rate: 9.949005546387623e-05
# Iteration 92, Loss: 5.59489631652832
# Iteration 92 - Learning Rate: 9.947880593013247e-05
# Iteration 93, Loss: 5.658694267272949
# Iteration 93 - Learning Rate: 9.946743431235362e-05
# Iteration 94, Loss: 5.852780342102051
# Iteration 94 - Learning Rate: 9.945594063859801e-05
# Iteration 95, Loss: 5.686972618103027
# Iteration 95 - Learning Rate: 9.944432493722516e-05
# Iteration 96, Loss: 5.593776702880859
# Iteration 96 - Learning Rate: 9.943258723689562e-05
# Iteration 97, Loss: 5.550092697143555
# Iteration 97 - Learning Rate: 9.942072756657104e-05
# Iteration 98, Loss: 5.455790996551514
# Iteration 98 - Learning Rate: 9.940874595551395e-05
# Iteration 99, Loss: 5.41318941116333
# Iteration 99 - Learning Rate: 9.93966424332878e-05
# Iteration 100, Loss: 5.632318019866943
# Iteration 100 - Learning Rate: 9.93844170297568e-05
# Iteration 101, Loss: 5.462559223175049
# Iteration 101 - Learning Rate: 9.937206977508596e-05
# Iteration 102, Loss: 5.228252410888672
# Iteration 102 - Learning Rate: 9.93596006997409e-05
# Iteration 103, Loss: 5.520210266113281
# Iteration 103 - Learning Rate: 9.934700983448778e-05
# Iteration 104, Loss: 5.557162284851074
# Iteration 104 - Learning Rate: 9.933429721039334e-05
# Iteration 105, Loss: 5.510648727416992
# Iteration 105 - Learning Rate: 9.932146285882471e-05
# Iteration 106, Loss: 34.541839599609375
# Iteration 106 - Learning Rate: 9.930850681144938e-05
# Iteration 107, Loss: 17.240310668945312
# Iteration 107 - Learning Rate: 9.92954291002351e-05
# Iteration 108, Loss: 5.539562225341797
# Iteration 108 - Learning Rate: 9.928222975744983e-05
# Iteration 109, Loss: 5.523889541625977
# Iteration 109 - Learning Rate: 9.926890881566163e-05
# Iteration 110, Loss: 5.465590476989746
# Iteration 110 - Learning Rate: 9.925546630773861e-05
# Iteration 111, Loss: 5.301586151123047
# Iteration 111 - Learning Rate: 9.924190226684882e-05
# Iteration 112, Loss: 5.81199836730957
# Iteration 112 - Learning Rate: 9.922821672646019e-05
# Iteration 113, Loss: 5.475860595703125
# Iteration 113 - Learning Rate: 9.921440972034041e-05
# Iteration 114, Loss: 5.30036735534668
# Iteration 114 - Learning Rate: 9.92004812825569e-05
# Iteration 115, Loss: 5.763588905334473
# Iteration 115 - Learning Rate: 9.918643144747671e-05
# Iteration 116, Loss: 5.628711700439453
# Iteration 116 - Learning Rate: 9.91722602497664e-05
# Iteration 117, Loss: 5.5137248039245605
# Iteration 117 - Learning Rate: 9.915796772439198e-05
# Iteration 118, Loss: 20.534963607788086
# Iteration 118 - Learning Rate: 9.914355390661886e-05
# Iteration 119, Loss: 5.850777626037598
# Iteration 119 - Learning Rate: 9.912901883201171e-05
# Iteration 120, Loss: 5.378610610961914
# Iteration 120 - Learning Rate: 9.911436253643436e-05
# Iteration 121, Loss: 5.412113189697266
# Iteration 121 - Learning Rate: 9.909958505604976e-05
# Iteration 122, Loss: 5.493208885192871
# Iteration 122 - Learning Rate: 9.908468642731987e-05
# Iteration 123, Loss: 5.249734878540039
# Iteration 123 - Learning Rate: 9.906966668700559e-05
# Iteration 124, Loss: 5.472969055175781
# Iteration 124 - Learning Rate: 9.905452587216663e-05
# Iteration 125, Loss: 5.586370468139648
# Iteration 125 - Learning Rate: 9.903926402016146e-05
# Iteration 126, Loss: 5.4317474365234375
# Iteration 126 - Learning Rate: 9.902388116864715e-05
# Iteration 127, Loss: 5.598171710968018
# Iteration 127 - Learning Rate: 9.900837735557939e-05
# Iteration 128, Loss: 5.648242473602295
# Iteration 128 - Learning Rate: 9.899275261921226e-05
# Iteration 129, Loss: 5.575264930725098
# Iteration 129 - Learning Rate: 9.897700699809829e-05
# Iteration 130, Loss: 5.315290927886963
# Iteration 130 - Learning Rate: 9.896114053108821e-05
# Iteration 131, Loss: 5.366546154022217
# Iteration 131 - Learning Rate: 9.894515325733095e-05
# Iteration 132, Loss: 5.533714294433594
# Iteration 132 - Learning Rate: 9.892904521627352e-05
# Iteration 133, Loss: 5.774110794067383
# Iteration 133 - Learning Rate: 9.891281644766092e-05
# Iteration 134, Loss: 5.378801345825195
# Iteration 134 - Learning Rate: 9.889646699153601e-05
# Iteration 135, Loss: 5.485339641571045
# Iteration 135 - Learning Rate: 9.887999688823946e-05
# Iteration 136, Loss: 5.381035327911377
# Iteration 136 - Learning Rate: 9.88634061784096e-05
# Iteration 137, Loss: 5.472746849060059
# Iteration 137 - Learning Rate: 9.884669490298236e-05
# Iteration 138, Loss: 5.548433303833008
# Iteration 138 - Learning Rate: 9.882986310319116e-05
# Iteration 139, Loss: 5.72464656829834
# Iteration 139 - Learning Rate: 9.881291082056677e-05
# Iteration 140, Loss: 5.291323661804199
# Iteration 140 - Learning Rate: 9.879583809693729e-05
# Iteration 141, Loss: 5.361372947692871
# Iteration 141 - Learning Rate: 9.877864497442795e-05
# Iteration 142, Loss: 5.50847053527832
# Iteration 142 - Learning Rate: 9.876133149546108e-05
# Iteration 143, Loss: 5.384524822235107
# Iteration 143 - Learning Rate: 9.874389770275599e-05
# Iteration 144, Loss: 5.346400260925293
# Iteration 144 - Learning Rate: 9.872634363932879e-05
# Iteration 145, Loss: 5.237972259521484
# Iteration 145 - Learning Rate: 9.87086693484924e-05
# Iteration 146, Loss: 5.7167463302612305
# Iteration 146 - Learning Rate: 9.869087487385635e-05
# Iteration 147, Loss: 5.461419582366943
# Iteration 147 - Learning Rate: 9.86729602593268e-05
# Iteration 148, Loss: 5.669842720031738
# Iteration 148 - Learning Rate: 9.865492554910625e-05
# Iteration 149, Loss: 14.31201457977295
# Iteration 149 - Learning Rate: 9.863677078769353e-05
# Iteration 150, Loss: 5.166818618774414
# Iteration 150 - Learning Rate: 9.861849601988375e-05
# Iteration 151, Loss: 5.492107391357422
# Iteration 151 - Learning Rate: 9.860010129076805e-05
# Iteration 152, Loss: 5.232483863830566
# Iteration 152 - Learning Rate: 9.858158664573363e-05
# Iteration 153, Loss: 5.436258316040039
# Iteration 153 - Learning Rate: 9.85629521304635e-05
# Iteration 154, Loss: 5.534647464752197
# Iteration 154 - Learning Rate: 9.854419779093649e-05
# Iteration 155, Loss: 5.431123733520508
# Iteration 155 - Learning Rate: 9.852532367342706e-05
# Iteration 156, Loss: 5.262881755828857
# Iteration 156 - Learning Rate: 9.850632982450523e-05
# Iteration 157, Loss: 5.360642910003662
# Iteration 157 - Learning Rate: 9.848721629103643e-05
# Iteration 158, Loss: 5.278600692749023
# Iteration 158 - Learning Rate: 9.846798312018139e-05
# Iteration 159, Loss: 5.3155317306518555
# Iteration 159 - Learning Rate: 9.844863035939609e-05
# Iteration 160, Loss: 5.440167427062988
# Iteration 160 - Learning Rate: 9.84291580564315e-05
# Iteration 161, Loss: 5.469246864318848
# Iteration 161 - Learning Rate: 9.84095662593336e-05
# Iteration 162, Loss: 5.143620014190674
# Iteration 162 - Learning Rate: 9.838985501644321e-05
# Iteration 163, Loss: 5.507819175720215
# Iteration 163 - Learning Rate: 9.837002437639586e-05
# Iteration 164, Loss: 5.622392654418945
# Iteration 164 - Learning Rate: 9.835007438812169e-05
# Iteration 165, Loss: 5.314213752746582
# Iteration 165 - Learning Rate: 9.83300051008453e-05
# Iteration 166, Loss: 5.609958648681641
# Iteration 166 - Learning Rate: 9.830981656408566e-05
# Iteration 167, Loss: 5.515397071838379
# Iteration 167 - Learning Rate: 9.828950882765601e-05
# Iteration 168, Loss: 5.581766128540039
# Iteration 168 - Learning Rate: 9.826908194166364e-05
# Iteration 169, Loss: 5.385770320892334
# Iteration 169 - Learning Rate: 9.824853595650986e-05
# Iteration 170, Loss: 5.414562225341797
# Iteration 170 - Learning Rate: 9.822787092288986e-05
# Iteration 171, Loss: 5.3130998611450195
# Iteration 171 - Learning Rate: 9.820708689179254e-05
# Iteration 172, Loss: 5.480918884277344
# Iteration 172 - Learning Rate: 9.818618391450043e-05
# Iteration 173, Loss: 5.3607988357543945
# Iteration 173 - Learning Rate: 9.816516204258957e-05
# Iteration 174, Loss: 5.434985160827637
# Iteration 174 - Learning Rate: 9.814402132792933e-05
# Iteration 175, Loss: 5.327631950378418
# Iteration 175 - Learning Rate: 9.812276182268231e-05
# Iteration 176, Loss: 5.445881366729736
# Iteration 176 - Learning Rate: 9.810138357930424e-05
# Iteration 177, Loss: 5.073864459991455
# Iteration 177 - Learning Rate: 9.80798866505438e-05
# Iteration 178, Loss: 5.181567192077637
# Iteration 178 - Learning Rate: 9.805827108944255e-05
# Iteration 179, Loss: 5.463411808013916
# Iteration 179 - Learning Rate: 9.803653694933471e-05
# Iteration 180, Loss: 5.424280643463135
# Iteration 180 - Learning Rate: 9.801468428384712e-05
# Iteration 181, Loss: 5.76411771774292
# Iteration 181 - Learning Rate: 9.799271314689904e-05
# Iteration 182, Loss: 5.377017498016357
# Iteration 182 - Learning Rate: 9.79706235927021e-05
# Iteration 183, Loss: 5.481589317321777
# Iteration 183 - Learning Rate: 9.794841567576007e-05
# Iteration 184, Loss: 5.3631463050842285
# Iteration 184 - Learning Rate: 9.792608945086875e-05
# Iteration 185, Loss: 5.645550727844238
# Iteration 185 - Learning Rate: 9.790364497311592e-05
# Iteration 186, Loss: 5.506409645080566
# Iteration 186 - Learning Rate: 9.788108229788105e-05
# Iteration 187, Loss: 5.308674335479736
# Iteration 187 - Learning Rate: 9.785840148083536e-05
# Iteration 188, Loss: 5.4189887046813965
# Iteration 188 - Learning Rate: 9.783560257794148e-05
# Iteration 189, Loss: 5.413028717041016
# Iteration 189 - Learning Rate: 9.781268564545342e-05
# Iteration 190, Loss: 5.341568946838379
# Iteration 190 - Learning Rate: 9.778965073991646e-05
# Iteration 191, Loss: 5.651890277862549
# Iteration 191 - Learning Rate: 9.776649791816693e-05
# Iteration 192, Loss: 5.203264236450195
# Iteration 192 - Learning Rate: 9.774322723733212e-05
# Iteration 193, Loss: 5.433569431304932
# Iteration 193 - Learning Rate: 9.77198387548301e-05
# Iteration 194, Loss: 5.450138092041016
# Iteration 194 - Learning Rate: 9.769633252836965e-05
# Iteration 195, Loss: 5.164302825927734
# Iteration 195 - Learning Rate: 9.767270861595003e-05
# Iteration 196, Loss: 5.2281036376953125
# Iteration 196 - Learning Rate: 9.764896707586092e-05
# Iteration 197, Loss: 5.2425618171691895
# Iteration 197 - Learning Rate: 9.762510796668217e-05
# Iteration 198, Loss: 5.174563407897949
# Iteration 198 - Learning Rate: 9.76011313472838e-05
# Iteration 199, Loss: 5.147553443908691
# Iteration 199 - Learning Rate: 9.75770372768257e-05
# Iteration 200, Loss: 5.333751201629639
# Iteration 200 - Learning Rate: 9.755282581475765e-05
# Iteration 201, Loss: 5.608841896057129
# Iteration 201 - Learning Rate: 9.752849702081897e-05
# Iteration 202, Loss: 5.483527183532715
# Iteration 202 - Learning Rate: 9.750405095503854e-05
# Iteration 203, Loss: 5.714929103851318
# Iteration 203 - Learning Rate: 9.747948767773464e-05
# Iteration 204, Loss: 5.673715591430664
# Iteration 204 - Learning Rate: 9.745480724951469e-05
# Iteration 205, Loss: 5.628846168518066
# Iteration 205 - Learning Rate: 9.743000973127519e-05
# Iteration 206, Loss: 5.381534576416016
# Iteration 206 - Learning Rate: 9.740509518420156e-05
# Iteration 207, Loss: 5.446882724761963
# Iteration 207 - Learning Rate: 9.738006366976798e-05
# Iteration 208, Loss: 5.181242942810059
# Iteration 208 - Learning Rate: 9.735491524973718e-05
# Iteration 209, Loss: 5.315146446228027
# Iteration 209 - Learning Rate: 9.732964998616044e-05
# Iteration 210, Loss: 5.7252020835876465
# Iteration 210 - Learning Rate: 9.730426794137724e-05
# Iteration 211, Loss: 5.418481349945068
# Iteration 211 - Learning Rate: 9.727876917801528e-05
# Iteration 212, Loss: 5.391005992889404
# Iteration 212 - Learning Rate: 9.725315375899021e-05
# Iteration 213, Loss: 5.418647289276123
# Iteration 213 - Learning Rate: 9.722742174750555e-05
# Iteration 214, Loss: 5.473421096801758
# Iteration 214 - Learning Rate: 9.720157320705247e-05
# Iteration 215, Loss: 5.305564880371094
# Iteration 215 - Learning Rate: 9.717560820140966e-05
# Iteration 216, Loss: 5.479527473449707
# Iteration 216 - Learning Rate: 9.714952679464321e-05
# Iteration 217, Loss: 5.393077850341797
# Iteration 217 - Learning Rate: 9.712332905110639e-05
# Iteration 218, Loss: 5.710897445678711
# Iteration 218 - Learning Rate: 9.709701503543952e-05
# Iteration 219, Loss: 5.281833648681641
# Iteration 219 - Learning Rate: 9.707058481256983e-05
# Iteration 220, Loss: 5.223837852478027
# Iteration 220 - Learning Rate: 9.704403844771127e-05
# Iteration 221, Loss: 5.2538628578186035
# Iteration 221 - Learning Rate: 9.701737600636435e-05
# Iteration 222, Loss: 5.471240997314453
# Iteration 222 - Learning Rate: 9.699059755431597e-05
# Iteration 223, Loss: 5.470980644226074
# Iteration 223 - Learning Rate: 9.696370315763935e-05
# Iteration 224, Loss: 5.174839973449707
# Iteration 224 - Learning Rate: 9.693669288269369e-05
# Iteration 225, Loss: 5.338586807250977
# Iteration 225 - Learning Rate: 9.69095667961242e-05
# Iteration 226, Loss: 5.346499443054199
# Iteration 226 - Learning Rate: 9.688232496486175e-05
# Iteration 227, Loss: 5.448851585388184
# Iteration 227 - Learning Rate: 9.685496745612292e-05
# Iteration 228, Loss: 5.416977405548096
# Iteration 228 - Learning Rate: 9.68274943374096e-05
# Iteration 229, Loss: 5.288666725158691
# Iteration 229 - Learning Rate: 9.679990567650897e-05
# Iteration 230, Loss: 5.342846870422363
# Iteration 230 - Learning Rate: 9.677220154149335e-05
# Iteration 231, Loss: 5.313028335571289
# Iteration 231 - Learning Rate: 9.674438200071988e-05
# Iteration 232, Loss: 5.327184200286865
# Iteration 232 - Learning Rate: 9.671644712283058e-05
# Iteration 233, Loss: 5.219757556915283
# Iteration 233 - Learning Rate: 9.668839697675193e-05
# Iteration 234, Loss: 5.314445495605469
# Iteration 234 - Learning Rate: 9.66602316316949e-05
# Iteration 235, Loss: 5.147404193878174
# Iteration 235 - Learning Rate: 9.663195115715468e-05
# Iteration 236, Loss: 5.3600077629089355
# Iteration 236 - Learning Rate: 9.660355562291052e-05
# Iteration 237, Loss: 5.455567836761475
# Iteration 237 - Learning Rate: 9.657504509902559e-05
# Iteration 238, Loss: 5.531710624694824
# Iteration 238 - Learning Rate: 9.654641965584676e-05
# Iteration 239, Loss: 5.486946105957031
# Iteration 239 - Learning Rate: 9.651767936400448e-05
# Iteration 240, Loss: 5.302851676940918
# Iteration 240 - Learning Rate: 9.648882429441254e-05
# Iteration 241, Loss: 5.3192830085754395
# Iteration 241 - Learning Rate: 9.6459854518268e-05
# Iteration 242, Loss: 5.277670860290527
# Iteration 242 - Learning Rate: 9.643077010705085e-05
# Iteration 243, Loss: 5.742710590362549
# Iteration 243 - Learning Rate: 9.640157113252402e-05
# Iteration 244, Loss: 5.615113258361816
# Iteration 244 - Learning Rate: 9.637225766673305e-05
# Iteration 245, Loss: 5.460981369018555
# Iteration 245 - Learning Rate: 9.634282978200603e-05
# Iteration 246, Loss: 5.297204971313477
# Iteration 246 - Learning Rate: 9.631328755095333e-05
# Iteration 247, Loss: 5.381026268005371
# Iteration 247 - Learning Rate: 9.628363104646747e-05
# Iteration 248, Loss: 5.497791290283203
# Iteration 248 - Learning Rate: 9.62538603417229e-05
# Iteration 249, Loss: 5.381301403045654
# Iteration 249 - Learning Rate: 9.622397551017592e-05
# Iteration 250, Loss: 5.2978196144104
# Iteration 250 - Learning Rate: 9.619397662556435e-05
# Iteration 251, Loss: 5.579643249511719
# Iteration 251 - Learning Rate: 9.616386376190745e-05
# Iteration 252, Loss: 5.277623653411865
# Iteration 252 - Learning Rate: 9.613363699350575e-05
# Iteration 253, Loss: 5.402002334594727
# Iteration 253 - Learning Rate: 9.610329639494076e-05
# Iteration 254, Loss: 5.201091766357422
# Iteration 254 - Learning Rate: 9.607284204107493e-05
# Iteration 255, Loss: 5.278209209442139
# Iteration 255 - Learning Rate: 9.604227400705133e-05
# Iteration 256, Loss: 5.539870262145996
# Iteration 256 - Learning Rate: 9.601159236829352e-05
# Iteration 257, Loss: 5.347896575927734
# Iteration 257 - Learning Rate: 9.598079720050542e-05
# Iteration 258, Loss: 5.329048156738281
# Iteration 258 - Learning Rate: 9.594988857967105e-05
# Iteration 259, Loss: 5.362712383270264
# Iteration 259 - Learning Rate: 9.591886658205436e-05
# Iteration 260, Loss: 5.720682144165039
# Iteration 260 - Learning Rate: 9.588773128419903e-05
# Iteration 261, Loss: 5.599302768707275
# Iteration 261 - Learning Rate: 9.585648276292833e-05
# Iteration 262, Loss: 5.638370037078857
# Iteration 262 - Learning Rate: 9.582512109534486e-05
# Iteration 263, Loss: 5.376665115356445
# Iteration 263 - Learning Rate: 9.579364635883045e-05
# Iteration 264, Loss: 5.357096195220947
# Iteration 264 - Learning Rate: 9.576205863104586e-05
# Iteration 265, Loss: 5.3557305335998535
# Iteration 265 - Learning Rate: 9.573035798993066e-05
# Iteration 266, Loss: 5.477913856506348
# Iteration 266 - Learning Rate: 9.569854451370304e-05
# Iteration 267, Loss: 5.342638969421387
# Iteration 267 - Learning Rate: 9.566661828085959e-05
# Iteration 268, Loss: 5.421595573425293
# Iteration 268 - Learning Rate: 9.563457937017513e-05
# Iteration 269, Loss: 5.278724193572998
# Iteration 269 - Learning Rate: 9.560242786070246e-05
# Iteration 270, Loss: 5.271615028381348
# Iteration 270 - Learning Rate: 9.557016383177224e-05
# Iteration 271, Loss: 5.294414520263672
# Iteration 271 - Learning Rate: 9.553778736299276e-05
# Iteration 272, Loss: 5.486636638641357
# Iteration 272 - Learning Rate: 9.550529853424976e-05
# Iteration 273, Loss: 5.328210830688477
# Iteration 273 - Learning Rate: 9.547269742570616e-05
# Iteration 274, Loss: 5.28015661239624
# Iteration 274 - Learning Rate: 9.543998411780199e-05
# Iteration 275, Loss: 5.4990434646606445
# Iteration 275 - Learning Rate: 9.540715869125404e-05
# Iteration 276, Loss: 5.215448379516602
# Iteration 276 - Learning Rate: 9.537422122705581e-05
# Iteration 277, Loss: 5.35080623626709
# Iteration 277 - Learning Rate: 9.534117180647724e-05
# Iteration 278, Loss: 5.321637153625488
# Iteration 278 - Learning Rate: 9.530801051106446e-05
# Iteration 279, Loss: 5.170207500457764
# Iteration 279 - Learning Rate: 9.527473742263969e-05
# Iteration 280, Loss: 5.2637529373168945
# Iteration 280 - Learning Rate: 9.524135262330094e-05
# Iteration 281, Loss: 5.260128021240234
# Iteration 281 - Learning Rate: 9.520785619542192e-05
# Iteration 282, Loss: 5.610905647277832
# Iteration 282 - Learning Rate: 9.517424822165171e-05
# Iteration 283, Loss: 5.3999834060668945
# Iteration 283 - Learning Rate: 9.514052878491465e-05
# Iteration 284, Loss: 5.407499313354492
# Iteration 284 - Learning Rate: 9.510669796841011e-05
# Iteration 285, Loss: 5.501408576965332
# Iteration 285 - Learning Rate: 9.507275585561226e-05
# Iteration 286, Loss: 5.486196517944336
# Iteration 286 - Learning Rate: 9.503870253026989e-05
# Iteration 287, Loss: 5.508184909820557
# Iteration 287 - Learning Rate: 9.500453807640617e-05
# Iteration 288, Loss: 5.508485794067383
# Iteration 288 - Learning Rate: 9.497026257831852e-05
# Iteration 289, Loss: 5.275430202484131
# Iteration 289 - Learning Rate: 9.493587612057833e-05
# Iteration 290, Loss: 5.345827102661133
# Iteration 290 - Learning Rate: 9.490137878803075e-05
# Iteration 291, Loss: 5.454511642456055
# Iteration 291 - Learning Rate: 9.486677066579452e-05
# Iteration 292, Loss: 5.335213661193848
# Iteration 292 - Learning Rate: 9.483205183926175e-05
# Iteration 293, Loss: 5.459447383880615
# Iteration 293 - Learning Rate: 9.479722239409769e-05
# Iteration 294, Loss: 5.2648820877075195
# Iteration 294 - Learning Rate: 9.476228241624054e-05
# Iteration 295, Loss: 5.546257972717285
# Iteration 295 - Learning Rate: 9.47272319919012e-05
# Iteration 296, Loss: 5.293505668640137
# Iteration 296 - Learning Rate: 9.469207120756313e-05
# Iteration 297, Loss: 5.695855140686035
# Iteration 297 - Learning Rate: 9.465680014998206e-05
# Iteration 298, Loss: 5.406966209411621
# Iteration 298 - Learning Rate: 9.462141890618584e-05
# Iteration 299, Loss: 5.249721050262451
# Iteration 299 - Learning Rate: 9.458592756347414e-05
# Iteration 300, Loss: 5.602597236633301
# Iteration 300 - Learning Rate: 9.455032620941833e-05
# Iteration 301, Loss: 5.262455940246582
# Iteration 301 - Learning Rate: 9.451461493186123e-05
# Iteration 302, Loss: 5.3038506507873535
# Iteration 302 - Learning Rate: 9.447879381891685e-05
# Iteration 303, Loss: 5.481733322143555
# Iteration 303 - Learning Rate: 9.444286295897021e-05
# Iteration 304, Loss: 5.676668167114258
# Iteration 304 - Learning Rate: 9.440682244067717e-05
# Iteration 305, Loss: 5.460454940795898
# Iteration 305 - Learning Rate: 9.437067235296411e-05
# Iteration 306, Loss: 5.542420387268066
# Iteration 306 - Learning Rate: 9.433441278502777e-05
# Iteration 307, Loss: 5.283454895019531
# Iteration 307 - Learning Rate: 9.429804382633503e-05
# Iteration 308, Loss: 5.368060111999512
# Iteration 308 - Learning Rate: 9.426156556662271e-05
# Iteration 309, Loss: 5.423666477203369
# Iteration 309 - Learning Rate: 9.422497809589724e-05
# Iteration 310, Loss: 5.276597023010254
# Iteration 310 - Learning Rate: 9.418828150443462e-05
# Iteration 311, Loss: 5.3872222900390625
# Iteration 311 - Learning Rate: 9.415147588277999e-05
# Iteration 312, Loss: 5.4585676193237305
# Iteration 312 - Learning Rate: 9.41145613217476e-05
# Iteration 313, Loss: 5.3360371589660645
# Iteration 313 - Learning Rate: 9.407753791242043e-05
# Iteration 314, Loss: 5.189311981201172
# Iteration 314 - Learning Rate: 9.404040574615011e-05
# Iteration 315, Loss: 5.350685119628906
# Iteration 315 - Learning Rate: 9.400316491455654e-05
# Iteration 316, Loss: 5.152341365814209
# Iteration 316 - Learning Rate: 9.396581550952774e-05
# Iteration 317, Loss: 5.205186367034912
# Iteration 317 - Learning Rate: 9.39283576232197e-05
# Iteration 318, Loss: 5.3057098388671875
# Iteration 318 - Learning Rate: 9.389079134805602e-05
# Iteration 319, Loss: 5.228638648986816
# Iteration 319 - Learning Rate: 9.385311677672774e-05
# Iteration 320, Loss: 5.296872138977051
# Iteration 320 - Learning Rate: 9.381533400219311e-05
# Iteration 321, Loss: 5.381587982177734
# Iteration 321 - Learning Rate: 9.377744311767739e-05
# Iteration 322, Loss: 5.180834770202637
# Iteration 322 - Learning Rate: 9.373944421667258e-05
# Iteration 323, Loss: 5.276782989501953
# Iteration 323 - Learning Rate: 9.370133739293716e-05
# Iteration 324, Loss: 5.307668209075928
# Iteration 324 - Learning Rate: 9.366312274049595e-05
# Iteration 325, Loss: 5.304095268249512
# Iteration 325 - Learning Rate: 9.36248003536398e-05
# Iteration 326, Loss: 5.33638858795166
# Iteration 326 - Learning Rate: 9.35863703269254e-05
# Iteration 327, Loss: 5.2059526443481445
# Iteration 327 - Learning Rate: 9.354783275517499e-05
# Iteration 328, Loss: 5.294648170471191
# Iteration 328 - Learning Rate: 9.350918773347623e-05
# Iteration 329, Loss: 5.259038925170898
# Iteration 329 - Learning Rate: 9.347043535718185e-05
# Iteration 330, Loss: 5.137572288513184
# Iteration 330 - Learning Rate: 9.34315757219095e-05
# Iteration 331, Loss: 5.196202278137207
# Iteration 331 - Learning Rate: 9.339260892354146e-05
# Iteration 332, Loss: 5.478899002075195
# Iteration 332 - Learning Rate: 9.335353505822444e-05
# Iteration 333, Loss: 5.401874542236328
# Iteration 333 - Learning Rate: 9.331435422236931e-05
# Iteration 334, Loss: 5.341061592102051
# Iteration 334 - Learning Rate: 9.327506651265089e-05
# Iteration 335, Loss: 5.204504013061523
# Iteration 335 - Learning Rate: 9.323567202600769e-05
# Iteration 336, Loss: 5.085915565490723
# Iteration 336 - Learning Rate: 9.31961708596417e-05
# Iteration 337, Loss: 5.207366943359375
# Iteration 337 - Learning Rate: 9.315656311101813e-05
# Iteration 338, Loss: 5.576224327087402
# Iteration 338 - Learning Rate: 9.311684887786514e-05
# Iteration 339, Loss: 5.280511379241943
# Iteration 339 - Learning Rate: 9.307702825817366e-05
# Iteration 340, Loss: 5.179939270019531
# Iteration 340 - Learning Rate: 9.303710135019713e-05
# Iteration 341, Loss: 5.324514389038086
# Iteration 341 - Learning Rate: 9.29970682524512e-05
# Iteration 342, Loss: 5.4160661697387695
# Iteration 342 - Learning Rate: 9.295692906371356e-05
# Iteration 343, Loss: 5.43562126159668
# Iteration 343 - Learning Rate: 9.291668388302367e-05
# Iteration 344, Loss: 5.374503135681152
# Iteration 344 - Learning Rate: 9.287633280968255e-05
# Iteration 345, Loss: 5.168794631958008
# Iteration 345 - Learning Rate: 9.283587594325242e-05
# Iteration 346, Loss: 5.414783477783203
# Iteration 346 - Learning Rate: 9.27953133835566e-05
# Iteration 347, Loss: 5.512024879455566
# Iteration 347 - Learning Rate: 9.275464523067913e-05
# Iteration 348, Loss: 5.373403549194336
# Iteration 348 - Learning Rate: 9.27138715849647e-05
# Iteration 349, Loss: 5.359455108642578
# Iteration 349 - Learning Rate: 9.267299254701818e-05
# Iteration 350, Loss: 5.697389602661133
# Iteration 350 - Learning Rate: 9.263200821770454e-05
# Iteration 351, Loss: 5.477804660797119
# Iteration 351 - Learning Rate: 9.259091869814855e-05
# Iteration 352, Loss: 5.223837852478027
# Iteration 352 - Learning Rate: 9.254972408973453e-05
# Iteration 353, Loss: 5.642597198486328
# Iteration 353 - Learning Rate: 9.250842449410605e-05
# Iteration 354, Loss: 5.379477500915527
# Iteration 354 - Learning Rate: 9.246702001316576e-05
# Iteration 355, Loss: 5.286858558654785
# Iteration 355 - Learning Rate: 9.242551074907512e-05
# Iteration 356, Loss: 5.358091354370117
# Iteration 356 - Learning Rate: 9.23838968042541e-05
# Iteration 357, Loss: 5.418406009674072
# Iteration 357 - Learning Rate: 9.234217828138097e-05
# Iteration 358, Loss: 5.404820442199707
# Iteration 358 - Learning Rate: 9.230035528339204e-05
# Iteration 359, Loss: 5.350983619689941
# Iteration 359 - Learning Rate: 9.22584279134814e-05
# Iteration 360, Loss: 5.412704944610596
# Iteration 360 - Learning Rate: 9.221639627510068e-05
# Iteration 361, Loss: 5.241427421569824
# Iteration 361 - Learning Rate: 9.217426047195876e-05
# Iteration 362, Loss: 5.513481140136719
# Iteration 362 - Learning Rate: 9.213202060802153e-05
# Iteration 363, Loss: 5.5161590576171875
# Iteration 363 - Learning Rate: 9.208967678751169e-05
# Iteration 364, Loss: 5.503802299499512
# Iteration 364 - Learning Rate: 9.204722911490837e-05
# Iteration 365, Loss: 5.317452907562256
# Iteration 365 - Learning Rate: 9.2004677694947e-05
# Iteration 366, Loss: 5.167423248291016
# Iteration 366 - Learning Rate: 9.196202263261899e-05
# Iteration 367, Loss: 5.31695556640625
# Iteration 367 - Learning Rate: 9.191926403317145e-05
# Iteration 368, Loss: 5.421809673309326
# Iteration 368 - Learning Rate: 9.1876402002107e-05
# Iteration 369, Loss: 5.446591377258301
# Iteration 369 - Learning Rate: 9.18334366451834e-05
# Iteration 370, Loss: 5.440523624420166
# Iteration 370 - Learning Rate: 9.179036806841344e-05
# Iteration 371, Loss: 5.4641642570495605
# Iteration 371 - Learning Rate: 9.174719637806451e-05
# Iteration 372, Loss: 5.7010087966918945
# Iteration 372 - Learning Rate: 9.170392168065848e-05
# Iteration 373, Loss: 5.500617027282715
# Iteration 373 - Learning Rate: 9.166054408297137e-05
# Iteration 374, Loss: 5.525111675262451
# Iteration 374 - Learning Rate: 9.16170636920331e-05
# Iteration 375, Loss: 5.629225730895996
# Iteration 375 - Learning Rate: 9.157348061512719e-05
# Iteration 376, Loss: 5.203861713409424
# Iteration 376 - Learning Rate: 9.152979495979055e-05
# Iteration 377, Loss: 5.380616188049316
# Iteration 377 - Learning Rate: 9.148600683381322e-05
# Iteration 378, Loss: 5.244297504425049
# Iteration 378 - Learning Rate: 9.1442116345238e-05
# Iteration 379, Loss: 5.275691986083984
# Iteration 379 - Learning Rate: 9.139812360236037e-05
# Iteration 380, Loss: 5.301755428314209
# Iteration 380 - Learning Rate: 9.1354028713728e-05
# Iteration 381, Loss: 5.469818115234375
# Iteration 381 - Learning Rate: 9.130983178814067e-05
# Iteration 382, Loss: 5.45674991607666
# Iteration 382 - Learning Rate: 9.12655329346499e-05
# Iteration 383, Loss: 5.70482873916626
# Iteration 383 - Learning Rate: 9.122113226255868e-05
# Iteration 384, Loss: 5.414944648742676
# Iteration 384 - Learning Rate: 9.117662988142128e-05
# Iteration 385, Loss: 5.202780246734619
# Iteration 385 - Learning Rate: 9.11320259010429e-05
# Iteration 386, Loss: 5.498774528503418
# Iteration 386 - Learning Rate: 9.108732043147942e-05
# Iteration 387, Loss: 5.22322940826416
# Iteration 387 - Learning Rate: 9.104251358303714e-05
# Iteration 388, Loss: 5.055147171020508
# Iteration 388 - Learning Rate: 9.099760546627253e-05
# Iteration 389, Loss: 5.22038459777832
# Iteration 389 - Learning Rate: 9.095259619199187e-05
# Iteration 390, Loss: 5.629880905151367
# Iteration 390 - Learning Rate: 9.090748587125109e-05
# Iteration 391, Loss: 5.44011116027832
# Iteration 391 - Learning Rate: 9.086227461535541e-05
# Iteration 392, Loss: 5.23641300201416
# Iteration 392 - Learning Rate: 9.081696253585911e-05
# Iteration 393, Loss: 5.540433883666992
# Iteration 393 - Learning Rate: 9.077154974456525e-05
# Iteration 394, Loss: 5.350894927978516
# Iteration 394 - Learning Rate: 9.072603635352539e-05
# Iteration 395, Loss: 5.256796360015869
# Iteration 395 - Learning Rate: 9.068042247503928e-05
# Iteration 396, Loss: 5.4054436683654785
# Iteration 396 - Learning Rate: 9.063470822165461e-05
# Iteration 397, Loss: 5.411823272705078
# Iteration 397 - Learning Rate: 9.05888937061668e-05
# Iteration 398, Loss: 5.501773834228516
# Iteration 398 - Learning Rate: 9.05429790416186e-05
# Iteration 399, Loss: 5.556759834289551
# Iteration 399 - Learning Rate: 9.049696434129986e-05
# Iteration 400, Loss: 5.692519187927246
# Iteration 400 - Learning Rate: 9.04508497187473e-05
# Iteration 401, Loss: 5.320507049560547
# Iteration 401 - Learning Rate: 9.040463528774416e-05
# Iteration 402, Loss: 5.43737268447876
# Iteration 402 - Learning Rate: 9.035832116231994e-05
# Iteration 403, Loss: 5.329365253448486
# Iteration 403 - Learning Rate: 9.031190745675017e-05
# Iteration 404, Loss: 5.277301788330078
# Iteration 404 - Learning Rate: 9.026539428555602e-05
# Iteration 405, Loss: 5.339668273925781
# Iteration 405 - Learning Rate: 9.021878176350415e-05
# Iteration 406, Loss: 5.239220142364502
# Iteration 406 - Learning Rate: 9.017207000560632e-05
# Iteration 407, Loss: 5.574260711669922
# Iteration 407 - Learning Rate: 9.012525912711913e-05
# Iteration 408, Loss: 5.2404608726501465
# Iteration 408 - Learning Rate: 9.007834924354378e-05
# Iteration 409, Loss: 5.26540470123291
# Iteration 409 - Learning Rate: 9.003134047062574e-05
# Iteration 410, Loss: 5.427834510803223
# Iteration 410 - Learning Rate: 8.998423292435448e-05
# Iteration 411, Loss: 5.1578474044799805
# Iteration 411 - Learning Rate: 8.993702672096319e-05
# Iteration 412, Loss: 5.469847679138184
# Iteration 412 - Learning Rate: 8.98897219769285e-05
# Iteration 413, Loss: 5.738158226013184
# Iteration 413 - Learning Rate: 8.984231880897015e-05
# Iteration 414, Loss: 5.337316036224365
# Iteration 414 - Learning Rate: 8.979481733405074e-05
# Iteration 415, Loss: 5.554604530334473
# Iteration 415 - Learning Rate: 8.974721766937545e-05
# Iteration 416, Loss: 5.396250247955322
# Iteration 416 - Learning Rate: 8.96995199323917e-05
# Iteration 417, Loss: 5.257643699645996
# Iteration 417 - Learning Rate: 8.965172424078896e-05
# Iteration 418, Loss: 5.092639923095703
# Iteration 418 - Learning Rate: 8.96038307124983e-05
# Iteration 419, Loss: 5.464555740356445
# Iteration 419 - Learning Rate: 8.955583946569226e-05
# Iteration 420, Loss: 5.350421905517578
# Iteration 420 - Learning Rate: 8.950775061878446e-05
# Iteration 421, Loss: 5.5004143714904785
# Iteration 421 - Learning Rate: 8.945956429042938e-05
# Iteration 422, Loss: 5.281397819519043
# Iteration 422 - Learning Rate: 8.941128059952195e-05
# Iteration 423, Loss: 5.216713905334473
# Iteration 423 - Learning Rate: 8.93628996651974e-05
# Iteration 424, Loss: 5.3247246742248535
# Iteration 424 - Learning Rate: 8.931442160683089e-05
# Iteration 425, Loss: 5.22006893157959
# Iteration 425 - Learning Rate: 8.926584654403719e-05
# Iteration 426, Loss: 5.350651741027832
# Iteration 426 - Learning Rate: 8.921717459667045e-05
# Iteration 427, Loss: 5.4058837890625
# Iteration 427 - Learning Rate: 8.916840588482386e-05
# Iteration 428, Loss: 5.320545673370361
# Iteration 428 - Learning Rate: 8.911954052882936e-05
# Iteration 429, Loss: 5.37607479095459
# Iteration 429 - Learning Rate: 8.907057864925736e-05
# Iteration 430, Loss: 5.26588773727417
# Iteration 430 - Learning Rate: 8.902152036691644e-05
# Iteration 431, Loss: 5.1795334815979
# Iteration 431 - Learning Rate: 8.897236580285303e-05
# Iteration 432, Loss: 5.464635372161865
# Iteration 432 - Learning Rate: 8.892311507835113e-05
# Iteration 433, Loss: 5.271304130554199
# Iteration 433 - Learning Rate: 8.8873768314932e-05
# Iteration 434, Loss: 5.338338851928711
# Iteration 434 - Learning Rate: 8.882432563435387e-05
# Iteration 435, Loss: 5.6804070472717285
# Iteration 435 - Learning Rate: 8.877478715861168e-05
# Iteration 436, Loss: 5.269290924072266
# Iteration 436 - Learning Rate: 8.872515300993665e-05
# Iteration 437, Loss: 5.146923065185547
# Iteration 437 - Learning Rate: 8.867542331079611e-05
# Iteration 438, Loss: 5.1875996589660645
# Iteration 438 - Learning Rate: 8.862559818389317e-05
# Iteration 439, Loss: 5.326548099517822
# Iteration 439 - Learning Rate: 8.857567775216636e-05
# Iteration 440, Loss: 5.423798561096191
# Iteration 440 - Learning Rate: 8.852566213878939e-05
# Iteration 441, Loss: 5.127685070037842
# Iteration 441 - Learning Rate: 8.847555146717083e-05
# Iteration 442, Loss: 5.291069030761719
# Iteration 442 - Learning Rate: 8.842534586095376e-05
# Iteration 443, Loss: 5.406652450561523
# Iteration 443 - Learning Rate: 8.837504544401553e-05
# Iteration 444, Loss: 5.206382751464844
# Iteration 444 - Learning Rate: 8.832465034046742e-05
# Iteration 445, Loss: 5.256573677062988
# Iteration 445 - Learning Rate: 8.827416067465434e-05
# Iteration 446, Loss: 5.288823127746582
# Iteration 446 - Learning Rate: 8.822357657115451e-05
# Iteration 447, Loss: 5.470322608947754
# Iteration 447 - Learning Rate: 8.81728981547792e-05
# Iteration 448, Loss: 5.508858680725098
# Iteration 448 - Learning Rate: 8.812212555057232e-05
# Iteration 449, Loss: 5.386208534240723
# Iteration 449 - Learning Rate: 8.807125888381025e-05
# Iteration 450, Loss: 5.323947906494141
# Iteration 450 - Learning Rate: 8.802029828000148e-05
# Iteration 451, Loss: 5.550514221191406
# Iteration 451 - Learning Rate: 8.796924386488614e-05
# Iteration 452, Loss: 5.477500915527344
# Iteration 452 - Learning Rate: 8.791809576443602e-05
# Iteration 453, Loss: 5.196595191955566
# Iteration 453 - Learning Rate: 8.78668541048539e-05
# Iteration 454, Loss: 5.21190881729126
# Iteration 454 - Learning Rate: 8.781551901257353e-05
# Iteration 455, Loss: 5.39570426940918
# Iteration 455 - Learning Rate: 8.77640906142591e-05
# Iteration 456, Loss: 5.607850074768066
# Iteration 456 - Learning Rate: 8.771256903680512e-05
# Iteration 457, Loss: 5.250363349914551
# Iteration 457 - Learning Rate: 8.766095440733593e-05
# Iteration 458, Loss: 5.227266311645508
# Iteration 458 - Learning Rate: 8.76092468532055e-05
# Iteration 459, Loss: 5.485752105712891
# Iteration 459 - Learning Rate: 8.75574465019971e-05
# Iteration 460, Loss: 5.294707775115967
# Iteration 460 - Learning Rate: 8.750555348152291e-05
# Iteration 461, Loss: 5.379473686218262
# Iteration 461 - Learning Rate: 8.745356791982383e-05
# Iteration 462, Loss: 5.5330610275268555
# Iteration 462 - Learning Rate: 8.740148994516904e-05
# Iteration 463, Loss: 5.58816385269165
# Iteration 463 - Learning Rate: 8.73493196860558e-05
# Iteration 464, Loss: 5.418213844299316
# Iteration 464 - Learning Rate: 8.729705727120904e-05
# Iteration 465, Loss: 5.0885467529296875
# Iteration 465 - Learning Rate: 8.724470282958103e-05
# Iteration 466, Loss: 5.321722984313965
# Iteration 466 - Learning Rate: 8.719225649035118e-05
# Iteration 467, Loss: 5.479091644287109
# Iteration 467 - Learning Rate: 8.713971838292561e-05
# Iteration 468, Loss: 5.192278861999512
# Iteration 468 - Learning Rate: 8.708708863693688e-05
# Iteration 469, Loss: 5.119400978088379
# Iteration 469 - Learning Rate: 8.703436738224367e-05
# Iteration 470, Loss: 5.6593780517578125
# Iteration 470 - Learning Rate: 8.69815547489304e-05
# Iteration 471, Loss: 5.385322570800781
# Iteration 471 - Learning Rate: 8.692865086730704e-05
# Iteration 472, Loss: 5.438943862915039
# Iteration 472 - Learning Rate: 8.687565586790862e-05
# Iteration 473, Loss: 5.332637786865234
# Iteration 473 - Learning Rate: 8.682256988149505e-05
# Iteration 474, Loss: 5.594922065734863
# Iteration 474 - Learning Rate: 8.676939303905072e-05
# Iteration 475, Loss: 5.578594207763672
# Iteration 475 - Learning Rate: 8.67161254717842e-05
# Iteration 476, Loss: 5.3065900802612305
# Iteration 476 - Learning Rate: 8.666276731112792e-05
# Iteration 477, Loss: 5.442162990570068
# Iteration 477 - Learning Rate: 8.660931868873783e-05
# Iteration 478, Loss: 5.29080867767334
# Iteration 478 - Learning Rate: 8.655577973649312e-05
# Iteration 479, Loss: 5.313804626464844
# Iteration 479 - Learning Rate: 8.65021505864958e-05
# Iteration 480, Loss: 5.515158653259277
# Iteration 480 - Learning Rate: 8.644843137107049e-05
# Iteration 481, Loss: 5.440438270568848
# Iteration 481 - Learning Rate: 8.6394622222764e-05
# Iteration 482, Loss: 5.201454162597656
# Iteration 482 - Learning Rate: 8.634072327434506e-05
# Iteration 483, Loss: 5.387505531311035
# Iteration 483 - Learning Rate: 8.628673465880396e-05
# Iteration 484, Loss: 5.253026962280273
# Iteration 484 - Learning Rate: 8.623265650935225e-05
# Iteration 485, Loss: 5.156106472015381
# Iteration 485 - Learning Rate: 8.617848895942238e-05
# Iteration 486, Loss: 5.261725902557373
# Iteration 486 - Learning Rate: 8.61242321426674e-05
# Iteration 487, Loss: 5.576140403747559
# Iteration 487 - Learning Rate: 8.606988619296061e-05
# Iteration 488, Loss: 5.458094596862793
# Iteration 488 - Learning Rate: 8.601545124439524e-05
# Iteration 489, Loss: 5.439948081970215
# Iteration 489 - Learning Rate: 8.596092743128412e-05
# Iteration 490, Loss: 5.388150215148926
# Iteration 490 - Learning Rate: 8.590631488815933e-05
# Iteration 491, Loss: 5.157739162445068
# Iteration 491 - Learning Rate: 8.58516137497719e-05
# Iteration 492, Loss: 5.501784324645996
# Iteration 492 - Learning Rate: 8.579682415109144e-05
# Iteration 493, Loss: 5.2125244140625
# Iteration 493 - Learning Rate: 8.574194622730585e-05
# Iteration 494, Loss: 5.4662184715271
# Iteration 494 - Learning Rate: 8.568698011382095e-05
# Iteration 495, Loss: 5.24979305267334
# Iteration 495 - Learning Rate: 8.563192594626016e-05
# Iteration 496, Loss: 5.544851779937744
# Iteration 496 - Learning Rate: 8.557678386046418e-05
# Iteration 497, Loss: 5.2707929611206055
# Iteration 497 - Learning Rate: 8.552155399249056e-05
# Iteration 498, Loss: 5.2427568435668945
# Iteration 498 - Learning Rate: 8.546623647861359e-05
# Iteration 499, Loss: 5.325067520141602
# Iteration 499 - Learning Rate: 8.54108314553237e-05
# Iteration 500, Loss: 5.428003311157227
# Iteration 500 - Learning Rate: 8.535533905932727e-05
# Iteration 501, Loss: 5.231371879577637
# Iteration 501 - Learning Rate: 8.529975942754629e-05
# Iteration 502, Loss: 5.337272644042969
# Iteration 502 - Learning Rate: 8.524409269711797e-05
# Iteration 503, Loss: 5.236072540283203
# Iteration 503 - Learning Rate: 8.518833900539443e-05
# Iteration 504, Loss: 5.255546569824219
# Iteration 504 - Learning Rate: 8.513249848994237e-05
# Iteration 505, Loss: 5.031044960021973
# Iteration 505 - Learning Rate: 8.50765712885427e-05
# Iteration 506, Loss: 5.398435592651367
# Iteration 506 - Learning Rate: 8.502055753919023e-05
# Iteration 507, Loss: 5.033906936645508
# Iteration 507 - Learning Rate: 8.496445738009333e-05
# Iteration 508, Loss: 5.584209442138672
# Iteration 508 - Learning Rate: 8.490827094967355e-05
# Iteration 509, Loss: 5.464712619781494
# Iteration 509 - Learning Rate: 8.485199838656533e-05
# Iteration 510, Loss: 5.396240234375
# Iteration 510 - Learning Rate: 8.479563982961563e-05
# Iteration 511, Loss: 5.394640922546387
# Iteration 511 - Learning Rate: 8.473919541788359e-05
# Iteration 512, Loss: 5.3390350341796875
# Iteration 512 - Learning Rate: 8.468266529064016e-05
# Iteration 513, Loss: 5.417989730834961
# Iteration 513 - Learning Rate: 8.462604958736785e-05
# Iteration 514, Loss: 5.38049840927124
# Iteration 514 - Learning Rate: 8.456934844776025e-05
# Iteration 515, Loss: 5.470346450805664
# Iteration 515 - Learning Rate: 8.45125620117218e-05
# Iteration 516, Loss: 5.201055526733398
# Iteration 516 - Learning Rate: 8.445569041936737e-05
# Iteration 517, Loss: 5.225026607513428
# Iteration 517 - Learning Rate: 8.439873381102196e-05
# Iteration 518, Loss: 5.373688697814941
# Iteration 518 - Learning Rate: 8.434169232722036e-05
# Iteration 519, Loss: 5.40385627746582
# Iteration 519 - Learning Rate: 8.428456610870673e-05
# Iteration 520, Loss: 5.455310821533203
# Iteration 520 - Learning Rate: 8.422735529643437e-05
# Iteration 521, Loss: 5.2998833656311035
# Iteration 521 - Learning Rate: 8.417006003156525e-05
# Iteration 522, Loss: 5.101917743682861
# Iteration 522 - Learning Rate: 8.411268045546976e-05
# Iteration 523, Loss: 5.4470062255859375
# Iteration 523 - Learning Rate: 8.405521670972628e-05
# Iteration 524, Loss: 5.289515495300293
# Iteration 524 - Learning Rate: 8.399766893612088e-05
# ...
# Iteration 1831, Loss: 5.351781845092773
# Iteration 1831 - Learning Rate: 1.7514640434900825e-06
# Iteration 1832, Loss: 5.599684715270996
# Iteration 1832 - Learning Rate: 1.730918058336302e-06
# Iteration 1833, Loss: 5.306377410888672
# Iteration 1833 - Learning Rate: 1.7104911723439269e-06
# Iteration 1834, Loss: 5.538908004760742
# Iteration 1834 - Learning Rate: 1.690183435914257e-06
# Iteration 1835, Loss: 5.184358596801758
# Iteration 1835 - Learning Rate: 1.669994899154638e-06
# Iteration 1836, Loss: 5.240190505981445
# Iteration 1836 - Learning Rate: 1.6499256118782462e-06
# Iteration 1837, Loss: 5.578334808349609
# Iteration 1837 - Learning Rate: 1.6299756236040703e-06
# Iteration 1838, Loss: 5.594285011291504
# Iteration 1838 - Learning Rate: 1.610144983556729e-06
# Iteration 1839, Loss: 5.292825222015381
# Iteration 1839 - Learning Rate: 1.5904337406663325e-06
# Iteration 1840, Loss: 5.43817138671875
# Iteration 1840 - Learning Rate: 1.5708419435684426e-06
# Iteration 1841, Loss: 5.421733856201172
# Iteration 1841 - Learning Rate: 1.5513696406038522e-06
# Iteration 1842, Loss: 5.372062683105469
# Iteration 1842 - Learning Rate: 1.532016879818534e-06
# Iteration 1843, Loss: 5.541893005371094
# Iteration 1843 - Learning Rate: 1.5127837089635077e-06
# Iteration 1844, Loss: 5.486511707305908
# Iteration 1844 - Learning Rate: 1.493670175494707e-06
# Iteration 1845, Loss: 5.515119552612305
# Iteration 1845 - Learning Rate: 1.4746763265728737e-06
# Iteration 1846, Loss: 5.360288619995117
# Iteration 1846 - Learning Rate: 1.4558022090634472e-06
# Iteration 1847, Loss: 5.252934455871582
# Iteration 1847 - Learning Rate: 1.4370478695364366e-06
# Iteration 1848, Loss: 5.414244651794434
# Iteration 1848 - Learning Rate: 1.4184133542662983e-06
# Iteration 1849, Loss: 5.191364288330078
# Iteration 1849 - Learning Rate: 1.3998987092318696e-06
# Iteration 1850, Loss: 5.115583419799805
# Iteration 1850 - Learning Rate: 1.381503980116169e-06
# Iteration 1851, Loss: 5.404409408569336
# Iteration 1851 - Learning Rate: 1.363229212306374e-06
# Iteration 1852, Loss: 5.194382190704346
# Iteration 1852 - Learning Rate: 1.345074450893671e-06
# Iteration 1853, Loss: 5.4913740158081055
# Iteration 1853 - Learning Rate: 1.3270397406731107e-06
# Iteration 1854, Loss: 5.594134330749512
# Iteration 1854 - Learning Rate: 1.3091251261435591e-06
# Iteration 1855, Loss: 5.264606952667236
# Iteration 1855 - Learning Rate: 1.29133065150753e-06
# Iteration 1856, Loss: 5.375822067260742
# Iteration 1856 - Learning Rate: 1.2736563606711354e-06
# Iteration 1857, Loss: 5.209485054016113
# Iteration 1857 - Learning Rate: 1.2561022972439411e-06
# Iteration 1858, Loss: 5.191007137298584
# Iteration 1858 - Learning Rate: 1.2386685045388286e-06
# Iteration 1859, Loss: 5.393984317779541
# Iteration 1859 - Learning Rate: 1.2213550255719601e-06
# Iteration 1860, Loss: 5.399364471435547
# Iteration 1860 - Learning Rate: 1.204161903062631e-06
# Iteration 1861, Loss: 5.091859340667725
# Iteration 1861 - Learning Rate: 1.1870891794331511e-06
# Iteration 1862, Loss: 5.648427963256836
# Iteration 1862 - Learning Rate: 1.1701368968087683e-06
# Iteration 1863, Loss: 5.621264457702637
# Iteration 1863 - Learning Rate: 1.1533050970175624e-06
# Iteration 1864, Loss: 5.504439830780029
# Iteration 1864 - Learning Rate: 1.1365938215903233e-06
# Iteration 1865, Loss: 5.339655876159668
# Iteration 1865 - Learning Rate: 1.1200031117604677e-06
# Iteration 1866, Loss: 5.762070178985596
# Iteration 1866 - Learning Rate: 1.1035330084639113e-06
# Iteration 1867, Loss: 5.336917400360107
# Iteration 1867 - Learning Rate: 1.0871835523389968e-06
# Iteration 1868, Loss: 5.099039554595947
# Iteration 1868 - Learning Rate: 1.070954783726394e-06
# Iteration 1869, Loss: 5.603562355041504
# Iteration 1869 - Learning Rate: 1.0548467426689663e-06
# Iteration 1870, Loss: 5.444799423217773
# Iteration 1870 - Learning Rate: 1.0388594689117044e-06
# Iteration 1871, Loss: 5.107511520385742
# Iteration 1871 - Learning Rate: 1.0229930019016315e-06
# Iteration 1872, Loss: 5.515093803405762
# Iteration 1872 - Learning Rate: 1.0072473807876542e-06
# Iteration 1873, Loss: 5.313727378845215
# Iteration 1873 - Learning Rate: 9.916226444205452e-07
# Iteration 1874, Loss: 5.280059814453125
# Iteration 1874 - Learning Rate: 9.76118831352782e-07
# Iteration 1875, Loss: 5.672153472900391
# Iteration 1875 - Learning Rate: 9.60735979838476e-07
# Iteration 1876, Loss: 5.515470504760742
# Iteration 1876 - Learning Rate: 9.454741278332987e-07
# Iteration 1877, Loss: 5.202945232391357
# Iteration 1877 - Learning Rate: 9.303333129943334e-07
# Iteration 1878, Loss: 5.152685165405273
# Iteration 1878 - Learning Rate: 9.153135726800575e-07
# Iteration 1879, Loss: 5.468129634857178
# Iteration 1879 - Learning Rate: 9.004149439501706e-07
# Iteration 1880, Loss: 5.17551326751709
# Iteration 1880 - Learning Rate: 8.856374635655617e-07
# Iteration 1881, Loss: 5.308310031890869
# Iteration 1881 - Learning Rate: 8.709811679882028e-07
# Iteration 1882, Loss: 5.162306785583496
# Iteration 1882 - Learning Rate: 8.56446093381039e-07
# Iteration 1883, Loss: 5.515896797180176
# Iteration 1883 - Learning Rate: 8.420322756079212e-07
# Iteration 1884, Loss: 5.235612869262695
# Iteration 1884 - Learning Rate: 8.277397502335115e-07
# Iteration 1885, Loss: 5.228513717651367
# Iteration 1885 - Learning Rate: 8.135685525232062e-07
# Iteration 1886, Loss: 5.472606658935547
# Iteration 1886 - Learning Rate: 7.995187174430131e-07
# Iteration 1887, Loss: 5.371832847595215
# Iteration 1887 - Learning Rate: 7.855902796595073e-07
# Iteration 1888, Loss: 5.487745761871338
# Iteration 1888 - Learning Rate: 7.717832735397314e-07
# Iteration 1889, Loss: 5.507025718688965
# Iteration 1889 - Learning Rate: 7.580977331510898e-07
# Iteration 1890, Loss: 5.4995317459106445
# Iteration 1890 - Learning Rate: 7.445336922613046e-07
# Iteration 1891, Loss: 5.662718772888184
# Iteration 1891 - Learning Rate: 7.310911843382875e-07
# Iteration 1892, Loss: 5.261251449584961
# Iteration 1892 - Learning Rate: 7.177702425500957e-07
# Iteration 1893, Loss: 5.496060371398926
# Iteration 1893 - Learning Rate: 7.045708997648318e-07
# Iteration 1894, Loss: 5.354108810424805
# Iteration 1894 - Learning Rate: 6.914931885505552e-07
# Iteration 1895, Loss: 5.535759925842285
# Iteration 1895 - Learning Rate: 6.785371411752265e-07
# Iteration 1896, Loss: 5.184518814086914
# Iteration 1896 - Learning Rate: 6.657027896065964e-07
# Iteration 1897, Loss: 5.392085075378418
# Iteration 1897 - Learning Rate: 6.529901655121555e-07
# Iteration 1898, Loss: 5.235006332397461
# Iteration 1898 - Learning Rate: 6.403993002590407e-07
# Iteration 1899, Loss: 5.4489641189575195
# Iteration 1899 - Learning Rate: 6.279302249139567e-07
# Iteration 1900, Loss: 5.386636257171631
# Iteration 1900 - Learning Rate: 6.155829702431153e-07
# Iteration 1901, Loss: 5.634980201721191
# Iteration 1901 - Learning Rate: 6.033575667121299e-07
# Iteration 1902, Loss: 5.233713150024414
# Iteration 1902 - Learning Rate: 5.912540444859765e-07
# Iteration 1903, Loss: 5.3737382888793945
# Iteration 1903 - Learning Rate: 5.792724334288829e-07
# Iteration 1904, Loss: 5.439837455749512
# Iteration 1904 - Learning Rate: 5.674127631043008e-07
# Iteration 1905, Loss: 5.31817102432251
# Iteration 1905 - Learning Rate: 5.556750627747726e-07
# Iteration 1906, Loss: 5.4500322341918945
# Iteration 1906 - Learning Rate: 5.440593614019091e-07
# Iteration 1907, Loss: 5.261580944061279
# Iteration 1907 - Learning Rate: 5.325656876463065e-07
# Iteration 1908, Loss: 5.328500747680664
# Iteration 1908 - Learning Rate: 5.211940698674518e-07
# Iteration 1909, Loss: 5.265333652496338
# Iteration 1909 - Learning Rate: 5.099445361236895e-07
# Iteration 1910, Loss: 5.307462692260742
# Iteration 1910 - Learning Rate: 4.988171141721218e-07
# Iteration 1911, Loss: 5.448555946350098
# Iteration 1911 - Learning Rate: 4.878118314685585e-07
# Iteration 1912, Loss: 5.2657670974731445
# Iteration 1912 - Learning Rate: 4.769287151674394e-07
# Iteration 1913, Loss: 5.237797737121582
# Iteration 1913 - Learning Rate: 4.6616779212177314e-07
# Iteration 1914, Loss: 5.019974231719971
# Iteration 1914 - Learning Rate: 4.555290888830653e-07
# Iteration 1915, Loss: 5.335700988769531
# Iteration 1915 - Learning Rate: 4.450126317012625e-07
# Iteration 1916, Loss: 5.560926914215088
# Iteration 1916 - Learning Rate: 4.3461844652466934e-07
# Iteration 1917, Loss: 5.474370002746582
# Iteration 1917 - Learning Rate: 4.243465589999151e-07
# Iteration 1918, Loss: 5.30960750579834
# Iteration 1918 - Learning Rate: 4.141969944718593e-07
# Iteration 1919, Loss: 5.240718364715576
# Iteration 1919 - Learning Rate: 4.0416977798353626e-07
# Iteration 1920, Loss: 5.17417573928833
# Iteration 1920 - Learning Rate: 3.9426493427611065e-07
# Iteration 1921, Loss: 5.1890549659729
# Iteration 1921 - Learning Rate: 3.8448248778879984e-07
# Iteration 1922, Loss: 5.600584983825684
# Iteration 1922 - Learning Rate: 3.7482246265881265e-07
# Iteration 1923, Loss: 5.398457050323486
# Iteration 1923 - Learning Rate: 3.652848827213108e-07
# Iteration 1924, Loss: 5.492369651794434
# Iteration 1924 - Learning Rate: 3.558697715093197e-07
# Iteration 1925, Loss: 5.1543288230896
# Iteration 1925 - Learning Rate: 3.465771522536844e-07
# Iteration 1926, Loss: 5.421486854553223
# Iteration 1926 - Learning Rate: 3.374070478830306e-07
# Iteration 1927, Loss: 5.551882743835449
# Iteration 1927 - Learning Rate: 3.2835948102367026e-07
# Iteration 1928, Loss: 5.513149261474609
# Iteration 1928 - Learning Rate: 3.1943447399957937e-07
# Iteration 1929, Loss: 5.490379333496094
# Iteration 1929 - Learning Rate: 3.106320488323258e-07
# Iteration 1930, Loss: 5.378962516784668
# Iteration 1930 - Learning Rate: 3.0195222724101386e-07
# Iteration 1931, Loss: 5.116867542266846
# Iteration 1931 - Learning Rate: 2.9339503064224536e-07
# Iteration 1932, Loss: 5.46640682220459
# Iteration 1932 - Learning Rate: 2.84960480150053e-07
# Iteration 1933, Loss: 5.444420337677002
# Iteration 1933 - Learning Rate: 2.766485965758506e-07
# Iteration 1934, Loss: 5.582996368408203
# Iteration 1934 - Learning Rate: 2.684594004283828e-07
# Iteration 1935, Loss: 5.680749893188477
# Iteration 1935 - Learning Rate: 2.603929119136753e-07
# Iteration 1936, Loss: 5.318539619445801
# Iteration 1936 - Learning Rate: 2.5244915093499054e-07
# Iteration 1937, Loss: 5.41030216217041
# Iteration 1937 - Learning Rate: 2.4462813709277203e-07
# Iteration 1938, Loss: 5.502744674682617
# Iteration 1938 - Learning Rate: 2.3692988968458324e-07
# Iteration 1939, Loss: 5.3917036056518555
# Iteration 1939 - Learning Rate: 2.2935442770509115e-07
# Iteration 1940, Loss: 5.4191999435424805
# Iteration 1940 - Learning Rate: 2.219017698459995e-07
# Iteration 1941, Loss: 5.3811235427856445
# Iteration 1941 - Learning Rate: 2.1457193449599332e-07
# Iteration 1942, Loss: 5.241715431213379
# Iteration 1942 - Learning Rate: 2.073649397407167e-07
# Iteration 1943, Loss: 5.489473342895508
# Iteration 1943 - Learning Rate: 2.0028080336271176e-07
# Iteration 1944, Loss: 5.72934627532959
# Iteration 1944 - Learning Rate: 1.9331954284137415e-07
# Iteration 1945, Loss: 5.283832550048828
# Iteration 1945 - Learning Rate: 1.864811753529366e-07
# Iteration 1946, Loss: 5.246504306793213
# Iteration 1946 - Learning Rate: 1.7976571777037986e-07
# Iteration 1947, Loss: 4.984579086303711
# Iteration 1947 - Learning Rate: 1.731731866634273e-07
# Iteration 1948, Loss: 5.160225868225098
# Iteration 1948 - Learning Rate: 1.6670359829850604e-07
# Iteration 1949, Loss: 5.324907302856445
# Iteration 1949 - Learning Rate: 1.6035696863866914e-07
# Iteration 1950, Loss: 5.310502052307129
# Iteration 1950 - Learning Rate: 1.5413331334360132e-07
# Iteration 1951, Loss: 5.366567611694336
# Iteration 1951 - Learning Rate: 1.4803264776955212e-07
# Iteration 1952, Loss: 5.079432487487793
# Iteration 1952 - Learning Rate: 1.4205498696930283e-07
# Iteration 1953, Loss: 5.2503275871276855
# Iteration 1953 - Learning Rate: 1.362003456921441e-07
# Iteration 1954, Loss: 5.326310634613037
# Iteration 1954 - Learning Rate: 1.30468738383815e-07
# Iteration 1955, Loss: 5.307076454162598
# Iteration 1955 - Learning Rate: 1.2486017918649742e-07
# Iteration 1956, Loss: 5.386322021484375
# Iteration 1956 - Learning Rate: 1.193746819387383e-07
# Iteration 1957, Loss: 5.3837995529174805
# Iteration 1957 - Learning Rate: 1.1401226017547192e-07
# Iteration 1958, Loss: 5.290085315704346
# Iteration 1958 - Learning Rate: 1.0877292712792551e-07
# Iteration 1959, Loss: 5.110157012939453
# Iteration 1959 - Learning Rate: 1.03656695723647e-07
# Iteration 1960, Loss: 5.50309419631958
# Iteration 1960 - Learning Rate: 9.866357858642173e-08
# Iteration 1961, Loss: 5.391411304473877
# Iteration 1961 - Learning Rate: 9.37935880362725e-08
# Iteration 1962, Loss: 5.396636009216309
# Iteration 1962 - Learning Rate: 8.904673608940954e-08
# Iteration 1963, Loss: 5.535648345947266
# Iteration 1963 - Learning Rate: 8.442303445823058e-08
# Iteration 1964, Loss: 5.487456321716309
# Iteration 1964 - Learning Rate: 7.992249455124863e-08
# Iteration 1965, Loss: 5.353077411651611
# Iteration 1965 - Learning Rate: 7.554512747310314e-08
# Iteration 1966, Loss: 5.156237602233887
# Iteration 1966 - Learning Rate: 7.129094402450997e-08
# Iteration 1967, Loss: 5.198415279388428
# Iteration 1967 - Learning Rate: 6.715995470225034e-08
# Iteration 1968, Loss: 5.296806335449219
# Iteration 1968 - Learning Rate: 6.315216969912642e-08
# Iteration 1969, Loss: 5.487953186035156
# Iteration 1969 - Learning Rate: 5.926759890394465e-08
# Iteration 1970, Loss: 5.380214691162109
# Iteration 1970 - Learning Rate: 5.550625190150464e-08
# Iteration 1971, Loss: 5.16812801361084
# Iteration 1971 - Learning Rate: 5.1868137972543694e-08
# Iteration 1972, Loss: 5.634819030761719
# Iteration 1972 - Learning Rate: 4.835326609376451e-08
# Iteration 1973, Loss: 5.424091815948486
# Iteration 1973 - Learning Rate: 4.496164493775197e-08
# Iteration 1974, Loss: 5.272348403930664
# Iteration 1974 - Learning Rate: 4.169328287299531e-08
# Iteration 1975, Loss: 5.255695343017578
# Iteration 1975 - Learning Rate: 3.8548187963854824e-08
# Iteration 1976, Loss: 5.347680568695068
# Iteration 1976 - Learning Rate: 3.5526367970539646e-08
# Iteration 1977, Loss: 5.086612701416016
# Iteration 1977 - Learning Rate: 3.262783034908557e-08
# Iteration 1978, Loss: 5.616671085357666
# Iteration 1978 - Learning Rate: 2.9852582251355024e-08
# Iteration 1979, Loss: 5.598411560058594
# Iteration 1979 - Learning Rate: 2.7200630524992686e-08
# Iteration 1980, Loss: 5.458852767944336
# Iteration 1980 - Learning Rate: 2.467198171341992e-08
# Iteration 1981, Loss: 5.334927082061768
# Iteration 1981 - Learning Rate: 2.226664205584032e-08
# Iteration 1982, Loss: 5.273766040802002
# Iteration 1982 - Learning Rate: 1.998461748717311e-08
# Iteration 1983, Loss: 5.400883674621582
# Iteration 1983 - Learning Rate: 1.7825913638097546e-08
# Iteration 1984, Loss: 5.304388999938965
# Iteration 1984 - Learning Rate: 1.5790535835002958e-08
# Iteration 1985, Loss: 5.408369541168213
# Iteration 1985 - Learning Rate: 1.3878489099972095e-08
# Iteration 1986, Loss: 5.369649887084961
# Iteration 1986 - Learning Rate: 1.2089778150797778e-08
# Iteration 1987, Loss: 5.1720075607299805
# Iteration 1987 - Learning Rate: 1.0424407400944048e-08
# Iteration 1988, Loss: 5.291049003601074
# Iteration 1988 - Learning Rate: 8.882380959551712e-09
# Iteration 1989, Loss: 5.270525932312012
# Iteration 1989 - Learning Rate: 7.463702631410585e-09
# Iteration 1990, Loss: 5.496527671813965
# Iteration 1990 - Learning Rate: 6.1683759169705955e-09
# Iteration 1991, Loss: 5.251470565795898
# Iteration 1991 - Learning Rate: 4.996404012325136e-09
# Iteration 1992, Loss: 5.463873863220215
# Iteration 1992 - Learning Rate: 3.947789809194401e-09
# Iteration 1993, Loss: 5.348114967346191
# Iteration 1993 - Learning Rate: 3.0225358949309463e-09
# Iteration 1994, Loss: 5.483619689941406
# Iteration 1994 - Learning Rate: 2.2206445525085812e-09
# Iteration 1995, Loss: 5.456334590911865
# Iteration 1995 - Learning Rate: 1.5421177605168208e-09
# Iteration 1996, Loss: 5.488409519195557
# Iteration 1996 - Learning Rate: 9.869571931442301e-10
# Iteration 1997, Loss: 5.301837921142578
# Iteration 1997 - Learning Rate: 5.551642202006305e-10
# Iteration 1998, Loss: 5.290182590484619
# Iteration 1998 - Learning Rate: 2.4673990708934305e-10
# Iteration 1999, Loss: 5.313793659210205
# Iteration 1999 - Learning Rate: 6.168501482384215e-11

# %%
print(torch.exp(model.data_transform.log_sigma))
print(model.data_transform.gamma)
# Out:
# tensor([1.9870, 2.9408], device='cuda:0', grad_fn=<ExpBackward0>)
# Parameter containing:
# tensor([-0.1146,  0.1899], device='cuda:0', requires_grad=True)

# %%
samples_obs, samples_std, samples_T= model.sample(n_samples)
plt.figure(figsize=(8,8))
plt.subplot(2, 2, 1)
plt.scatter(samples_obs[:,0].cpu().data.numpy(), samples_obs[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples on observational scale')
plt.subplot(2, 2, 2)
plt.scatter(samples_std[:,0].cpu().data.numpy(), samples_std[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples on standardized scale')
plt.subplot(2, 2, 3)
plt.scatter(samples_T[:,0].cpu().data.numpy(), samples_T[:,1].cpu().data.numpy(), alpha=0.5, color='red')
plt.title('Samples from Normalizing Flow')
plt.show()

# %%
plt.subplot(1, 2, 1)
sns.distplot(samples[:,0], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
sns.distplot(samples_obs[:,0].cpu().data.numpy(), hist=False, kde=True,
             bins=None, color='firebrick',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='flow')
plt.title(r'$p(x_1)$')
plt.subplot(1, 2, 2)
sns.distplot(samples[:,1], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
sns.distplot(samples_obs[:,1].cpu().data.numpy(), hist=False, kde=True,
             bins=None, color='firebrick',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='flow')
plt.title(r'$p(x_2)$')
plt.show()
# Out:
# /tmp/ipykernel_4131848/2014099692.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,0], hist=False, kde=True,
# /tmp/ipykernel_4131848/2014099692.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples_obs[:,0].cpu().data.numpy(), hist=False, kde=True,
# /tmp/ipykernel_4131848/2014099692.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,1], hist=False, kde=True,
# /tmp/ipykernel_4131848/2014099692.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples_obs[:,1].cpu().data.numpy(), hist=False, kde=True,

# %%
sns.distplot(samples[:,1], hist=False, kde=True,
             bins=None,
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2},
             label='data')
# Out:
# /tmp/ipykernel_4131848/2863656582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(samples[:,1], hist=False, kde=True,
# <Axes: ylabel='Density'>

# %%
def empirical_upper_tail_dependence(X1, X2, q):
    """
    Calculate empirical upper tail dependence coefficient.

    Parameters:
    X1, X2 : numpy arrays
        Samples from two random variables.
    q : float
        Quantile threshold (close to 1, e.g., 0.95 or 0.99).

    Returns:
    lambda_u : float
        Empirical upper tail dependence coefficient.
    """
    # Compute the quantiles
    F1_q = np.quantile(X1, q)
    F2_q = np.quantile(X2, q)
    
    # Count joint exceedances
    joint_exceedance = np.sum((X1 > F1_q) & (X2 > F2_q))
    exceedance_X1 = np.sum(X1 > F1_q)
    
    # Calculate lambda_u
    if exceedance_X1 == 0:  # Avoid division by zero
        return 0.0
    lambda_u = joint_exceedance / exceedance_X1
    return lambda_u


def plot_tail_dependence(X1, X2, quantiles):
    """
    Plot upper tail dependence vs quantiles.

    Parameters:
    X1, X2 : numpy arrays
        Samples from two random variables.
    quantiles : list or array
        List of quantiles to evaluate (e.g., np.linspace(0.9, 0.99, 50)).
    """
    # Compute lambda_u for each quantile
    lambda_values = [empirical_upper_tail_dependence(X1, X2, q) for q in quantiles]
    
    # Plot the results
    plt.figure(figsize=(8, 6))
    plt.plot(quantiles, lambda_values, marker='o', linestyle='-')
    plt.xlabel('Quantile (q)')
    plt.ylabel(r'$\lambda_u$ (Upper Tail Dependence)')
    plt.title('Upper Tail Dependence vs Quantiles')
    plt.grid(True)
    plt.show()

# Example usage
np.random.seed(42)
X1 = samples[:,0]
X2 = samples[:,1]

# Define quantiles (e.g., from 0.90 to 0.99)
quantiles = np.linspace(0.50, 0.990, 100)

# Plot the tail dependence
plot_tail_dependence(X1, X2, quantiles)
# Compute lambda_u at 0.95 quantile
q = 0.99
lambda_u = empirical_upper_tail_dependence(X1, X2, q)
print(f"Empirical upper tail dependence: {lambda_u}")
# Out:
# Empirical upper tail dependence: 0.53

# %%
X1 = samples_obs[:,0].cpu().data.numpy()
X2 = samples_obs[:,1].cpu().data.numpy()

# Define quantiles (e.g., from 0.90 to 0.99)
quantiles = np.linspace(0.50, 0.990, 100)

# Plot the tail dependence
plot_tail_dependence(X1, X2, quantiles)
# Compute lambda_u at 0.95 quantile
q = 0.99
lambda_u = empirical_upper_tail_dependence(X1, X2, q)
print(f"Empirical upper tail dependence: {lambda_u}")
# Out:
# Empirical upper tail dependence: 0.53
